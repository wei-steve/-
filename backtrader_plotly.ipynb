# %%
import pandas as pd
import sqlite3
import backtrader as bt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import dash
from dash import Dash, dcc, html, Input, Output, State, clientside_callback, no_update
import dash_bootstrap_components as dbc
import numpy as np
from datetime import datetime
from io import StringIO

# 导入策略
try:
    from strategies.kama_strategy import KAMAStrategy
    from strategies.rsi_strategy import RSIStrategy
    print("成功导入 KAMAStrategy 和 RSIStrategy")
except ImportError as e:
    print(f"导入失败：{e}")
    raise

# 数据加载函数
def load_kline_data(db_path, coin_name='LEAUSDT', interval='1m', limit=600, offset=0):
    try:
        conn = sqlite3.connect(db_path)
        query = f"""
            SELECT timestamp, open, high, low, close, volume
            FROM kline_data
            WHERE coin_name = ? AND interval = ?
            ORDER BY timestamp DESC
            LIMIT ? OFFSET ?
        """
        df = pd.read_sql_query(query, conn, params=(coin_name, interval, limit, offset))
        conn.close()
        
        if df.empty:
            print("警告：数据库返回空数据")
            return pd.DataFrame()
        
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
        df.set_index('timestamp', inplace=True)
        df = df.sort_index()
        df.columns = ['open', 'high', 'low', 'close', 'volume']
        
        if df[['open', 'high', 'low', 'close']].le(0).any().any() or df.isna().any().any():
            print("警告：数据包含零、负值或 NaN")
            df = df[(df[['open', 'high', 'low', 'close']] > 0).all(axis=1)].dropna()
        
        print(f"加载数据：{len(df)} 条，时间范围：{df.index.min()} 到 {df.index.max()}")
        print(f"价格范围：open {df['open'].min()} - {df['open'].max()}, close {df['close'].min()} - {df['close'].max()}")
        
        return df
    except Exception as e:
        print(f"数据加载错误：{e}")
        return pd.DataFrame()

# Backtrader 数据馈送
class PandasData(bt.feeds.PandasData):
    params = (
        ('datetime', None),
        ('open', 'open'),
        ('high', 'high'),
        ('low', 'low'),
        ('close', 'close'),
        ('volume', 'volume'),
        ('openinterest', None),
    )

# 回测函数
def run_backtest(data, strategy_class, **strategy_params):
    if data.empty or len(data) < max([v for k, v in strategy_params.items() if 'period' in k.lower()] or [10]):
        print("错误：数据不足，无法回测")
        return None, pd.DataFrame(), pd.DataFrame()
    
    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy_class, **strategy_params)
    
    data_feed = PandasData(dataname=data)
    cerebro.adddata(data_feed)
    
    cerebro.broker.setcash(1000000)
    cerebro.broker.setcommission(commission=0.001)
    
    try:
        cerebro.run()
        strategy = cerebro.runstrats[0][0]
        trades = strategy.trades
        
        if trades:
            trades_df = pd.DataFrame(trades)
            buy_signals = trades_df[trades_df['Size'] > 0][['EntryTime', 'EntryPrice']]
            sell_signals = trades_df[trades_df['Size'] < 0][['EntryTime', 'EntryPrice']]
        else:
            buy_signals = pd.DataFrame(columns=['EntryTime', 'EntryPrice'])
            sell_signals = pd.DataFrame(columns=['EntryTime', 'EntryPrice'])
        
        final_value = cerebro.broker.getvalue()
        initial_value = 1000000
        returns = (final_value - initial_value) / initial_value * 100
        stats = {
            'Return [%]': returns,
            'Max. Drawdown [%]': 0,
            '# Trades': len(trades),
            'Win Rate [%]': 0,
        }
        
        print(f"回测完成：交易次数 {len(trades)}")
        return stats, buy_signals, sell_signals
    except Exception as e:
        print(f"回测错误：{e}")
        return None, pd.DataFrame(), pd.DataFrame()

# 绘图函数
def create_kline_plot(data, buy_signals, sell_signals, strategy_type='kama', indicator_values=None, indicator_name='Indicator'):
    if data.empty:
        print("警告：无数据，无法绘图")
        return go.Figure()
    
    if strategy_type == 'rsi':
        fig = make_subplots(rows=3, cols=1, shared_xaxes=True,
                            vertical_spacing=0.03, subplot_titles=('K线图', '成交量', 'RSI'),
                            row_heights=[0.5, 0.2, 0.3])
    else:
        fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
                            vertical_spacing=0.03, subplot_titles=('K线图', '成交量'),
                            row_heights=[0.7, 0.3])
    
    fig.add_trace(
        go.Candlestick(
            x=data.index,
            open=data['open'], high=data['high'],
            low=data['low'], close=data['close'],
            name='K线'
        ),
        row=1, col=1
    )
    
    if indicator_values is not None:
        if strategy_type == 'kama':
            fig.add_trace(
                go.Scatter(x=data.index, y=indicator_values, name=indicator_name, line=dict(color='orange')),
                row=1, col=1
            )
        elif strategy_type == 'rsi':
            fig.add_trace(
                go.Scatter(x=data.index, y=indicator_values, name='RSI', line=dict(color='purple')),
                row=3, col=1
            )
            fig.add_shape(
                type='line', x0=data.index.min(), x1=data.index.max(),
                y0=70, y1=70, line=dict(color='red', dash='dash'),
                row=3, col=1
            )
            fig.add_shape(
                type='line', x0=data.index.min(), x1=data.index.max(),
                y0=30, y1=30, line=dict(color='green', dash='dash'),
                row=3, col=1
            )
    
    if not buy_signals.empty:
        fig.add_trace(
            go.Scatter(
                x=buy_signals['EntryTime'], y=buy_signals['EntryPrice'],
                mode='markers', name='买入',
                marker=dict(symbol='triangle-up', size=10, color='green')
            ),
            row=1, col=1
        )
    if not sell_signals.empty:
        fig.add_trace(
            go.Scatter(
                x=sell_signals['EntryTime'], y=sell_signals['EntryPrice'],
                mode='markers', name='卖出',
                marker=dict(symbol='triangle-down', size=10, color='red')
            ),
            row=1, col=1
        )
    
    fig.add_trace(
        go.Bar(x=data.index, y=data['volume'], name='成交量', marker_color='blue'),
        row=2, col=1
    )
    
    if len(data) >= 200:
        end_date = data.index.max()
        start_date = data.index[-200]
        xaxis_range = [start_date, end_date]
    else:
        xaxis_range = [data.index.min(), data.index.max()]
    
    fig.update_layout(
        xaxis_rangeslider_visible=False,
        dragmode='pan',
        template='plotly_dark',
        hovermode='x unified',
        showlegend=True,
        height=800 if strategy_type == 'rsi' else 600,
        autosize=True,
        xaxis=dict(range=xaxis_range)
    )
    fig.update_xaxes(
        rangebreaks=[dict(bounds=['sat', 'mon'])]
    )
    
    return fig

# Dash 应用
app = Dash(__name__, external_stylesheets=[dbc.themes.DARKLY], suppress_callback_exceptions=True)

# 数据库路径
DB_PATH = r'D:\策略研究\kline_db_new\kline_data_LEAUSDT.db'

# 初始数据
initial_data = load_kline_data(DB_PATH, limit=600)

# 计算 KAMA
def calculate_kama(series, period=3, fast_period=2, slow_period=30):
    kama = np.zeros(len(series))
    kama[0] = series[0]
    fast = 2 / (fast_period + 1)
    slow = 2 / (slow_period + 1)
    
    for i in range(1, len(series)):
        if i < period:
            kama[i] = series[i]
            continue
        change = abs(series[i] - series[i - period])
        volatility = sum(abs(series[j] - series[j-1]) for j in range(i - period + 1, i + 1))
        er = change / volatility if volatility != 0 else 0
        sc = (er * (fast - slow) + slow) ** 2
        kama[i] = kama[i-1] + sc * (series[i] - kama[i-1])
    
    return kama

# 计算 RSI
def calculate_rsi(series, period=14):
    delta = np.diff(series)
    gain = np.where(delta > 0, delta, 0)
    loss = np.where(delta < 0, -delta, 0)
    
    avg_gain = np.zeros(len(series))
    avg_loss = np.zeros(len(series))
    avg_gain[period] = np.mean(gain[:period])
    avg_loss[period] = np.mean(loss[:period])
    
    for i in range(period + 1, len(gain)):
        avg_gain[i] = (avg_gain[i-1] * (period - 1) + gain[i-1]) / period
        avg_loss[i] = (avg_loss[i-1] * (period - 1) + loss[i-1]) / period
    
    rs = np.divide(avg_gain, avg_loss, out=np.zeros_like(avg_gain), where=avg_loss != 0)
    rsi = 100 - (100 / (1 + rs))
    rsi[:period] = np.nan
    return rsi

# 初始回测（默认 KAMA）
initial_stats, initial_buy_signals, initial_sell_signals = run_backtest(
    initial_data, KAMAStrategy, kama_period=3, fast_period=2, slow_period=30
)

# 初始 KAMA 指标
initial_kama = calculate_kama(initial_data['close'].values, period=3)
print(f"KAMA 范围：{initial_kama.min():.6f} - {initial_kama.max():.6f}")

# 初始 RSI 指标
initial_rsi = calculate_rsi(initial_data['close'].values, period=14)
print(f"RSI 范围：{np.nanmin(initial_rsi):.2f} - {np.nanmax(initial_rsi):.2f}")

# 初始图表
initial_fig = create_kline_plot(
    initial_data, initial_buy_signals, initial_sell_signals,
    strategy_type='kama', indicator_values=initial_kama, indicator_name='KAMA3'
)

# 布局
app.layout = dbc.Container([
    html.H1('LEAUSDT 策略回测', style={'textAlign': 'center'}),
    dbc.Row([
        dbc.Col([
            html.Label('选择策略'),
            dcc.Dropdown(
                id='strategy-select',
                options=[
                    {'label': 'KAMA', 'value': 'kama'},
                    {'label': 'RSI', 'value': 'rsi'},
                ],
                value='kama'
            ),
            html.Div(id='strategy-params'),
            html.Br(),
            dbc.Button('更新回测', id='update-btn', color='primary', n_clicks=0),
            html.Br(),
            html.Label('加载历史数据'),
            dbc.Button('加载更多', id='load-more', color='secondary', n_clicks=0),
        ], width=3),
        dbc.Col([
            dcc.Graph(id='kline-plot', figure=initial_fig, config={'scrollZoom': True}),
            html.Div(id='stats-output')
        ], width=9)
    ]),
    dcc.Store(id='data-store', data=initial_data.to_json(date_format='iso', orient='split')),
    dcc.Store(id='offset-store', data=0),
    dcc.Store(id='kama-params', data={'kama_period': 3, 'fast_period': 2, 'slow_period': 30}),
    dcc.Store(id='rsi-params', data={'rsi_period': 14, 'overbought': 70, 'oversold': 30}),
], fluid=True)

# 动态参数输入框
@app.callback(
    Output('strategy-params', 'children'),
    Input('strategy-select', 'value'),
    State('kama-params', 'data'),
    State('rsi-params', 'data')
)
def update_params(strategy, kama_params, rsi_params):
    kama_params = kama_params or {'kama_period': 3, 'fast_period': 2, 'slow_period': 30}
    rsi_params = rsi_params or {'rsi_period': 14, 'overbought': 70, 'oversold': 30}
    
    if strategy == 'kama':
        return [
            html.Label('KAMA 周期'),
            dcc.Input(id='kama-period', type='number', value=kama_params['kama_period'], min=1, step=1),
            html.Label('快周期'),
            dcc.Input(id='fast-period', type='number', value=kama_params['fast_period'], min=1, step=1),
            html.Label('慢周期'),
            dcc.Input(id='slow-period', type='number', value=kama_params['slow_period'], min=1, step=1),
        ]
    elif strategy == 'rsi':
        return [
            html.Label('RSI 周期'),
            dcc.Input(id='rsi-period', type='number', value=rsi_params['rsi_period'], min=1, step=1),
            html.Label('超买阈值'),
            dcc.Input(id='overbought', type='number', value=rsi_params['overbought'], min=0, max=100, step=1),
            html.Label('超卖阈值'),
            dcc.Input(id='oversold', type='number', value=rsi_params['oversold'], min=0, max=100, step=1),
        ]
    return []

# 客户端回调：保存 KAMA 参数
clientside_callback(
    """
    function(kama_period, fast_period, slow_period) {
        return {
            'kama_period': kama_period || 3,
            'fast_period': fast_period || 2,
            'slow_period': slow_period || 30
        };
    }
    """,
    Output('kama-params', 'data'),
    [Input('kama-period', 'value'),
     Input('fast-period', 'value'),
     Input('slow-period', 'value')]
)

# 客户端回调：保存 RSI 参数
clientside_callback(
    """
    function(rsi_period, overbought, oversold) {
        return {
            'rsi_period': rsi_period || 14,
            'overbought': overbought || 70,
            'oversold': oversold || 30
        };
    }
    """,
    Output('rsi-params', 'data'),
    [Input('rsi-period', 'value'),
     Input('overbought', 'value'),
     Input('oversold', 'value')]
)

# 更新图表和统计
@app.callback(
    [Output('kline-plot', 'figure'),
     Output('stats-output', 'children'),
     Output('data-store', 'data'),
     Output('offset-store', 'data')],
    [Input('update-btn', 'n_clicks'),
     Input('load-more', 'n_clicks')],
    [State('strategy-select', 'value'),
     State('kama-params', 'data'),
     State('rsi-params', 'data'),
     State('data-store', 'data'),
     State('offset-store', 'data')]
)
def update_plot(update_clicks, load_clicks, strategy, kama_params, rsi_params, stored_data, offset):
    kama_params = kama_params or {'kama_period': 3, 'fast_period': 2, 'slow_period': 30}
    rsi_params = rsi_params or {'rsi_period': 14, 'overbought': 70, 'oversold': 30}
    
    data = pd.read_json(StringIO(stored_data), orient='split')
    data.index = pd.to_datetime(data.index)
    
    triggered_id = dash.callback_context.triggered[0]['prop_id'].split('.')[0]
    if triggered_id == 'load-more' and load_clicks > 0:
        new_offset = offset + 100
        new_data = load_kline_data(DB_PATH, limit=100, offset=new_offset)
        if not new_data.empty:
            data = pd.concat([new_data, data]).sort_index()
    else:
        new_offset = offset
    
    if strategy == 'kama':
        stats, buy_signals, sell_signals = run_backtest(
            data, KAMAStrategy,
            kama_period=kama_params['kama_period'],
            fast_period=kama_params['fast_period'],
            slow_period=kama_params['slow_period']
        )
        indicator_values = calculate_kama(data['close'].values,
                                         period=kama_params['kama_period'],
                                         fast_period=kama_params['fast_period'],
                                         slow_period=kama_params['slow_period'])
        fig = create_kline_plot(
            data, buy_signals, sell_signals,
            strategy_type='kama',
            indicator_values=indicator_values,
            indicator_name=f'KAMA{kama_params["kama_period"]}'
        )
    else:  # rsi
        stats, buy_signals, sell_signals = run_backtest(
            data, RSIStrategy,
            rsi_period=rsi_params['rsi_period'],
            overbought=rsi_params['overbought'],
            oversold=rsi_params['oversold']
        )
        indicator_values = calculate_rsi(data['close'].values, period=rsi_params['rsi_period'])
        fig = create_kline_plot(
            data, buy_signals, sell_signals,
            strategy_type='rsi',
            indicator_values=indicator_values,
            indicator_name='RSI'
        )
    
    if stats is None:
        stats_text = [html.P("无足够数据进行回测")]
    else:
        stats_text = [
            html.P(f"总回报: {stats['Return [%]']:.2f}%"),
            html.P(f"最大回撤: {stats['Max. Drawdown [%]']:.2f}%"),
            html.P(f"交易次数: {stats['# Trades']}"),
            html.P(f"胜率: {stats['Win Rate [%]']:.2f}%")
        ]
    
    data_json = data.to_json(date_format='iso', orient='split')
    return fig, stats_text, data_json, new_offset

# 滚动加载
@app.callback(
    [Output('kline-plot', 'figure', allow_duplicate=True),
     Output('data-store', 'data', allow_duplicate=True),
     Output('offset-store', 'data', allow_duplicate=True)],
    Input('kline-plot', 'relayoutData'),
    [State('data-store', 'data'),
     State('offset-store', 'data'),
     State('strategy-select', 'value'),
     State('kama-params', 'data'),
     State('rsi-params', 'data')],
    prevent_initial_call=True
)
def load_on_scroll(relayout_data, stored_data, offset, strategy, kama_params, rsi_params):
    kama_params = kama_params or {'kama_period': 3, 'fast_period': 2, 'slow_period': 30}
    rsi_params = rsi_params or {'rsi_period': 14, 'overbought': 70, 'oversold': 30}
    
    if relayout_data and 'xaxis.range[0]' in relayout_data:
        data = pd.read_json(StringIO(stored_data), orient='split')
        data.index = pd.to_datetime(data.index)
        start_date = pd.to_datetime(relayout_data['xaxis.range[0]'])
        
        if start_date <= data.index[:100].max():
            new_offset = offset + 100
            new_data = load_kline_data(DB_PATH, limit=100, offset=new_offset)
            if not new_data.empty:
                data = pd.concat([new_data, data]).sort_index()
                if strategy == 'kama':
                    stats, buy_signals, sell_signals = run_backtest(
                        data, KAMAStrategy,
                        kama_period=kama_params['kama_period'],
                        fast_period=kama_params['fast_period'],
                        slow_period=kama_params['slow_period']
                    )
                    indicator_values = calculate_kama(data['close'].values,
                                                     period=kama_params['kama_period'],
                                                     fast_period=kama_params['fast_period'],
                                                     slow_period=kama_params['slow_period'])
                    fig = create_kline_plot(
                        data, buy_signals, sell_signals,
                        strategy_type='kama',
                        indicator_values=indicator_values,
                        indicator_name=f'KAMA{kama_params["kama_period"]}'
                    )
                else:  # rsi
                    stats, buy_signals, sell_signals = run_backtest(
                        data, RSIStrategy,
                        rsi_period=rsi_params['rsi_period'],
                        overbought=rsi_params['overbought'],
                        oversold=rsi_params['oversold']
                    )
                    indicator_values = calculate_rsi(data['close'].values, period=rsi_params['rsi_period'])
                    fig = create_kline_plot(
                        data, buy_signals, sell_signals,
                        strategy_type='rsi',
                        indicator_values=indicator_values,
                        indicator_name='RSI'
                    )
                data_json = data.to_json(date_format='iso', orient='split')
                return fig, data_json, new_offset
    return no_update, no_update, no_update

# 运行应用
if __name__ == '__main__':
    app.run(debug=True)
# Out:
# 成功导入 KAMAStrategy 和 RSIStrategy
# 加载数据：600 条，时间范围：2025-04-16 18:44:00 到 2025-04-17 04:43:00
# 价格范围：open 0.00298764 - 0.00452598, close 0.00298764 - 0.00452598
# 执行 next：时间 2025-04-16 18:46:00
# 检查交叉：时间 2025-04-16 18:46:00, Close 0.003406, KAMA nan, Prev Close 0.003389, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:47:00
# 检查交叉：时间 2025-04-16 18:47:00, Close 0.003365, KAMA nan, Prev Close 0.003406, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:48:00
# 检查交叉：时间 2025-04-16 18:48:00, Close 0.003442, KAMA nan, Prev Close 0.003365, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:49:00
# 检查交叉：时间 2025-04-16 18:49:00, Close 0.003447, KAMA nan, Prev Close 0.003442, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:50:00
# 检查交叉：时间 2025-04-16 18:50:00, Close 0.003509, KAMA nan, Prev Close 0.003447, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:51:00
# 检查交叉：时间 2025-04-16 18:51:00, Close 0.003423, KAMA nan, Prev Close 0.003509, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:52:00
# 检查交叉：时间 2025-04-16 18:52:00, Close 0.003339, KAMA nan, Prev Close 0.003423, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:53:00
# 检查交叉：时间 2025-04-16 18:53:00, Close 0.003412, KAMA nan, Prev Close 0.003339, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:54:00
# 检查交叉：时间 2025-04-16 18:54:00, Close 0.003475, KAMA nan, Prev Close 0.003412, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:55:00
# 检查交叉：时间 2025-04-16 18:55:00, Close 0.003408, KAMA nan, Prev Close 0.003475, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:56:00
# 检查交叉：时间 2025-04-16 18:56:00, Close 0.003423, KAMA nan, Prev Close 0.003408, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:57:00
# 检查交叉：时间 2025-04-16 18:57:00, Close 0.003418, KAMA nan, Prev Close 0.003423, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:58:00
# 检查交叉：时间 2025-04-16 18:58:00, Close 0.003384, KAMA nan, Prev Close 0.003418, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 18:59:00
# 检查交叉：时间 2025-04-16 18:59:00, Close 0.003388, KAMA nan, Prev Close 0.003384, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:00:00
# 检查交叉：时间 2025-04-16 19:00:00, Close 0.003421, KAMA nan, Prev Close 0.003388, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:01:00
# 检查交叉：时间 2025-04-16 19:01:00, Close 0.003406, KAMA nan, Prev Close 0.003421, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:02:00
# 检查交叉：时间 2025-04-16 19:02:00, Close 0.003465, KAMA nan, Prev Close 0.003406, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:03:00
# 检查交叉：时间 2025-04-16 19:03:00, Close 0.003397, KAMA nan, Prev Close 0.003465, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:04:00
# 检查交叉：时间 2025-04-16 19:04:00, Close 0.003466, KAMA nan, Prev Close 0.003397, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:05:00
# 检查交叉：时间 2025-04-16 19:05:00, Close 0.003429, KAMA nan, Prev Close 0.003466, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:06:00
# 检查交叉：时间 2025-04-16 19:06:00, Close 0.003467, KAMA nan, Prev Close 0.003429, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:07:00
# 检查交叉：时间 2025-04-16 19:07:00, Close 0.003490, KAMA nan, Prev Close 0.003467, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:08:00
# 检查交叉：时间 2025-04-16 19:08:00, Close 0.003396, KAMA nan, Prev Close 0.003490, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:09:00
# 检查交叉：时间 2025-04-16 19:09:00, Close 0.003356, KAMA nan, Prev Close 0.003396, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:10:00
# 检查交叉：时间 2025-04-16 19:10:00, Close 0.003382, KAMA nan, Prev Close 0.003356, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:11:00
# 检查交叉：时间 2025-04-16 19:11:00, Close 0.003298, KAMA nan, Prev Close 0.003382, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:12:00
# 检查交叉：时间 2025-04-16 19:12:00, Close 0.003254, KAMA nan, Prev Close 0.003298, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:13:00
# 检查交叉：时间 2025-04-16 19:13:00, Close 0.003242, KAMA nan, Prev Close 0.003254, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:14:00
# 检查交叉：时间 2025-04-16 19:14:00, Close 0.003291, KAMA nan, Prev Close 0.003242, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:15:00
# 检查交叉：时间 2025-04-16 19:15:00, Close 0.003279, KAMA nan, Prev Close 0.003291, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:16:00
# 检查交叉：时间 2025-04-16 19:16:00, Close 0.003258, KAMA nan, Prev Close 0.003279, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:17:00
# 检查交叉：时间 2025-04-16 19:17:00, Close 0.003206, KAMA nan, Prev Close 0.003258, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:18:00
# 检查交叉：时间 2025-04-16 19:18:00, Close 0.003219, KAMA nan, Prev Close 0.003206, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:19:00
# 检查交叉：时间 2025-04-16 19:19:00, Close 0.003267, KAMA nan, Prev Close 0.003219, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:20:00
# 检查交叉：时间 2025-04-16 19:20:00, Close 0.003193, KAMA nan, Prev Close 0.003267, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:21:00
# 检查交叉：时间 2025-04-16 19:21:00, Close 0.003127, KAMA nan, Prev Close 0.003193, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:22:00
# 检查交叉：时间 2025-04-16 19:22:00, Close 0.003237, KAMA nan, Prev Close 0.003127, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:23:00
# 检查交叉：时间 2025-04-16 19:23:00, Close 0.003277, KAMA nan, Prev Close 0.003237, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:24:00
# 检查交叉：时间 2025-04-16 19:24:00, Close 0.003364, KAMA nan, Prev Close 0.003277, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:25:00
# 检查交叉：时间 2025-04-16 19:25:00, Close 0.003237, KAMA nan, Prev Close 0.003364, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:26:00
# 检查交叉：时间 2025-04-16 19:26:00, Close 0.003235, KAMA nan, Prev Close 0.003237, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:27:00
# 检查交叉：时间 2025-04-16 19:27:00, Close 0.003226, KAMA nan, Prev Close 0.003235, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:28:00
# 检查交叉：时间 2025-04-16 19:28:00, Close 0.003249, KAMA nan, Prev Close 0.003226, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:29:00
# 检查交叉：时间 2025-04-16 19:29:00, Close 0.003326, KAMA nan, Prev Close 0.003249, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:30:00
# 检查交叉：时间 2025-04-16 19:30:00, Close 0.003271, KAMA nan, Prev Close 0.003326, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:31:00
# 检查交叉：时间 2025-04-16 19:31:00, Close 0.003246, KAMA nan, Prev Close 0.003271, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:32:00
# 检查交叉：时间 2025-04-16 19:32:00, Close 0.003291, KAMA nan, Prev Close 0.003246, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:33:00
# 检查交叉：时间 2025-04-16 19:33:00, Close 0.003270, KAMA nan, Prev Close 0.003291, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:34:00
# 检查交叉：时间 2025-04-16 19:34:00, Close 0.003229, KAMA nan, Prev Close 0.003270, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:35:00
# 检查交叉：时间 2025-04-16 19:35:00, Close 0.003232, KAMA nan, Prev Close 0.003229, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:36:00
# 检查交叉：时间 2025-04-16 19:36:00, Close 0.003205, KAMA nan, Prev Close 0.003232, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:37:00
# 检查交叉：时间 2025-04-16 19:37:00, Close 0.003234, KAMA nan, Prev Close 0.003205, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:38:00
# 检查交叉：时间 2025-04-16 19:38:00, Close 0.003271, KAMA nan, Prev Close 0.003234, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:39:00
# 检查交叉：时间 2025-04-16 19:39:00, Close 0.003207, KAMA nan, Prev Close 0.003271, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:40:00
# 检查交叉：时间 2025-04-16 19:40:00, Close 0.003242, KAMA nan, Prev Close 0.003207, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:41:00
# 检查交叉：时间 2025-04-16 19:41:00, Close 0.003291, KAMA nan, Prev Close 0.003242, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:42:00
# 检查交叉：时间 2025-04-16 19:42:00, Close 0.003236, KAMA nan, Prev Close 0.003291, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:43:00
# 检查交叉：时间 2025-04-16 19:43:00, Close 0.003199, KAMA nan, Prev Close 0.003236, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:44:00
# 检查交叉：时间 2025-04-16 19:44:00, Close 0.003259, KAMA nan, Prev Close 0.003199, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:45:00
# 检查交叉：时间 2025-04-16 19:45:00, Close 0.003191, KAMA nan, Prev Close 0.003259, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:46:00
# 检查交叉：时间 2025-04-16 19:46:00, Close 0.003191, KAMA nan, Prev Close 0.003191, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:47:00
# 检查交叉：时间 2025-04-16 19:47:00, Close 0.003283, KAMA nan, Prev Close 0.003191, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:48:00
# 检查交叉：时间 2025-04-16 19:48:00, Close 0.003307, KAMA nan, Prev Close 0.003283, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:49:00
# 检查交叉：时间 2025-04-16 19:49:00, Close 0.003311, KAMA nan, Prev Close 0.003307, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:50:00
# 检查交叉：时间 2025-04-16 19:50:00, Close 0.003205, KAMA nan, Prev Close 0.003311, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:51:00
# 检查交叉：时间 2025-04-16 19:51:00, Close 0.003140, KAMA nan, Prev Close 0.003205, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:52:00
# 检查交叉：时间 2025-04-16 19:52:00, Close 0.003260, KAMA nan, Prev Close 0.003140, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:53:00
# 检查交叉：时间 2025-04-16 19:53:00, Close 0.003257, KAMA nan, Prev Close 0.003260, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:54:00
# 检查交叉：时间 2025-04-16 19:54:00, Close 0.003273, KAMA nan, Prev Close 0.003257, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:55:00
# 检查交叉：时间 2025-04-16 19:55:00, Close 0.003282, KAMA nan, Prev Close 0.003273, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:56:00
# 检查交叉：时间 2025-04-16 19:56:00, Close 0.003332, KAMA nan, Prev Close 0.003282, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:57:00
# 检查交叉：时间 2025-04-16 19:57:00, Close 0.003382, KAMA nan, Prev Close 0.003332, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:58:00
# 检查交叉：时间 2025-04-16 19:58:00, Close 0.003444, KAMA nan, Prev Close 0.003382, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 19:59:00
# 检查交叉：时间 2025-04-16 19:59:00, Close 0.003439, KAMA nan, Prev Close 0.003444, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:00:00
# 检查交叉：时间 2025-04-16 20:00:00, Close 0.003390, KAMA nan, Prev Close 0.003439, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:01:00
# 检查交叉：时间 2025-04-16 20:01:00, Close 0.003372, KAMA nan, Prev Close 0.003390, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:02:00
# 检查交叉：时间 2025-04-16 20:02:00, Close 0.003346, KAMA nan, Prev Close 0.003372, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:03:00
# 检查交叉：时间 2025-04-16 20:03:00, Close 0.003370, KAMA nan, Prev Close 0.003346, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:04:00
# 检查交叉：时间 2025-04-16 20:04:00, Close 0.003356, KAMA nan, Prev Close 0.003370, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:05:00
# 检查交叉：时间 2025-04-16 20:05:00, Close 0.003321, KAMA nan, Prev Close 0.003356, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:06:00
# 检查交叉：时间 2025-04-16 20:06:00, Close 0.003293, KAMA nan, Prev Close 0.003321, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:07:00
# 检查交叉：时间 2025-04-16 20:07:00, Close 0.003263, KAMA nan, Prev Close 0.003293, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:08:00
# 检查交叉：时间 2025-04-16 20:08:00, Close 0.003273, KAMA nan, Prev Close 0.003263, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:09:00
# 检查交叉：时间 2025-04-16 20:09:00, Close 0.003301, KAMA nan, Prev Close 0.003273, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:10:00
# 检查交叉：时间 2025-04-16 20:10:00, Close 0.003297, KAMA nan, Prev Close 0.003301, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:11:00
# 检查交叉：时间 2025-04-16 20:11:00, Close 0.003343, KAMA nan, Prev Close 0.003297, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:12:00
# 检查交叉：时间 2025-04-16 20:12:00, Close 0.003382, KAMA nan, Prev Close 0.003343, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:13:00
# 检查交叉：时间 2025-04-16 20:13:00, Close 0.003311, KAMA nan, Prev Close 0.003382, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:14:00
# 检查交叉：时间 2025-04-16 20:14:00, Close 0.003308, KAMA nan, Prev Close 0.003311, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:15:00
# 检查交叉：时间 2025-04-16 20:15:00, Close 0.003316, KAMA nan, Prev Close 0.003308, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:16:00
# 检查交叉：时间 2025-04-16 20:16:00, Close 0.003296, KAMA nan, Prev Close 0.003316, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:17:00
# 检查交叉：时间 2025-04-16 20:17:00, Close 0.003389, KAMA nan, Prev Close 0.003296, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:18:00
# 检查交叉：时间 2025-04-16 20:18:00, Close 0.003385, KAMA nan, Prev Close 0.003389, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:19:00
# 检查交叉：时间 2025-04-16 20:19:00, Close 0.003397, KAMA nan, Prev Close 0.003385, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:20:00
# 检查交叉：时间 2025-04-16 20:20:00, Close 0.003395, KAMA nan, Prev Close 0.003397, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:21:00
# 检查交叉：时间 2025-04-16 20:21:00, Close 0.003404, KAMA nan, Prev Close 0.003395, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:22:00
# 检查交叉：时间 2025-04-16 20:22:00, Close 0.003364, KAMA nan, Prev Close 0.003404, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:23:00
# 检查交叉：时间 2025-04-16 20:23:00, Close 0.003390, KAMA nan, Prev Close 0.003364, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:24:00
# 检查交叉：时间 2025-04-16 20:24:00, Close 0.003325, KAMA nan, Prev Close 0.003390, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:25:00
# 检查交叉：时间 2025-04-16 20:25:00, Close 0.003360, KAMA nan, Prev Close 0.003325, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:26:00
# 检查交叉：时间 2025-04-16 20:26:00, Close 0.003382, KAMA nan, Prev Close 0.003360, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:27:00
# 检查交叉：时间 2025-04-16 20:27:00, Close 0.003389, KAMA nan, Prev Close 0.003382, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:28:00
# 检查交叉：时间 2025-04-16 20:28:00, Close 0.003354, KAMA nan, Prev Close 0.003389, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:29:00
# 检查交叉：时间 2025-04-16 20:29:00, Close 0.003346, KAMA nan, Prev Close 0.003354, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:30:00
# 检查交叉：时间 2025-04-16 20:30:00, Close 0.003304, KAMA nan, Prev Close 0.003346, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:31:00
# 检查交叉：时间 2025-04-16 20:31:00, Close 0.003327, KAMA nan, Prev Close 0.003304, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:32:00
# 检查交叉：时间 2025-04-16 20:32:00, Close 0.003376, KAMA nan, Prev Close 0.003327, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:33:00
# 检查交叉：时间 2025-04-16 20:33:00, Close 0.003406, KAMA nan, Prev Close 0.003376, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:34:00
# 检查交叉：时间 2025-04-16 20:34:00, Close 0.003307, KAMA nan, Prev Close 0.003406, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:35:00
# 检查交叉：时间 2025-04-16 20:35:00, Close 0.003306, KAMA nan, Prev Close 0.003307, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:36:00
# 检查交叉：时间 2025-04-16 20:36:00, Close 0.003357, KAMA nan, Prev Close 0.003306, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:37:00
# 检查交叉：时间 2025-04-16 20:37:00, Close 0.003346, KAMA nan, Prev Close 0.003357, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:38:00
# 检查交叉：时间 2025-04-16 20:38:00, Close 0.003362, KAMA nan, Prev Close 0.003346, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:39:00
# 检查交叉：时间 2025-04-16 20:39:00, Close 0.003362, KAMA nan, Prev Close 0.003362, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:40:00
# 检查交叉：时间 2025-04-16 20:40:00, Close 0.003312, KAMA nan, Prev Close 0.003362, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:41:00
# 检查交叉：时间 2025-04-16 20:41:00, Close 0.003290, KAMA nan, Prev Close 0.003312, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:42:00
# 检查交叉：时间 2025-04-16 20:42:00, Close 0.003355, KAMA nan, Prev Close 0.003290, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:43:00
# 检查交叉：时间 2025-04-16 20:43:00, Close 0.003423, KAMA nan, Prev Close 0.003355, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:44:00
# 检查交叉：时间 2025-04-16 20:44:00, Close 0.003400, KAMA nan, Prev Close 0.003423, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:45:00
# 检查交叉：时间 2025-04-16 20:45:00, Close 0.003353, KAMA nan, Prev Close 0.003400, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:46:00
# 检查交叉：时间 2025-04-16 20:46:00, Close 0.003324, KAMA nan, Prev Close 0.003353, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:47:00
# 检查交叉：时间 2025-04-16 20:47:00, Close 0.003305, KAMA nan, Prev Close 0.003324, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:48:00
# 检查交叉：时间 2025-04-16 20:48:00, Close 0.003257, KAMA nan, Prev Close 0.003305, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:49:00
# 检查交叉：时间 2025-04-16 20:49:00, Close 0.003229, KAMA nan, Prev Close 0.003257, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:50:00
# 检查交叉：时间 2025-04-16 20:50:00, Close 0.003165, KAMA nan, Prev Close 0.003229, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:51:00
# 检查交叉：时间 2025-04-16 20:51:00, Close 0.003164, KAMA nan, Prev Close 0.003165, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:52:00
# 检查交叉：时间 2025-04-16 20:52:00, Close 0.003084, KAMA nan, Prev Close 0.003164, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:53:00
# 检查交叉：时间 2025-04-16 20:53:00, Close 0.003141, KAMA nan, Prev Close 0.003084, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:54:00
# 检查交叉：时间 2025-04-16 20:54:00, Close 0.003114, KAMA nan, Prev Close 0.003141, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:55:00
# 检查交叉：时间 2025-04-16 20:55:00, Close 0.003060, KAMA nan, Prev Close 0.003114, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:56:00
# 检查交叉：时间 2025-04-16 20:56:00, Close 0.003023, KAMA nan, Prev Close 0.003060, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:57:00
# 检查交叉：时间 2025-04-16 20:57:00, Close 0.003094, KAMA nan, Prev Close 0.003023, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:58:00
# 检查交叉：时间 2025-04-16 20:58:00, Close 0.003133, KAMA nan, Prev Close 0.003094, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 20:59:00
# 检查交叉：时间 2025-04-16 20:59:00, Close 0.003232, KAMA nan, Prev Close 0.003133, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:00:00
# 检查交叉：时间 2025-04-16 21:00:00, Close 0.003172, KAMA nan, Prev Close 0.003232, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:01:00
# 检查交叉：时间 2025-04-16 21:01:00, Close 0.003158, KAMA nan, Prev Close 0.003172, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:02:00
# 检查交叉：时间 2025-04-16 21:02:00, Close 0.003133, KAMA nan, Prev Close 0.003158, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:03:00
# 检查交叉：时间 2025-04-16 21:03:00, Close 0.003137, KAMA nan, Prev Close 0.003133, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:04:00
# 检查交叉：时间 2025-04-16 21:04:00, Close 0.003194, KAMA nan, Prev Close 0.003137, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:05:00
# 检查交叉：时间 2025-04-16 21:05:00, Close 0.003202, KAMA nan, Prev Close 0.003194, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:06:00
# 检查交叉：时间 2025-04-16 21:06:00, Close 0.003217, KAMA nan, Prev Close 0.003202, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:07:00
# 检查交叉：时间 2025-04-16 21:07:00, Close 0.003191, KAMA nan, Prev Close 0.003217, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:08:00
# 检查交叉：时间 2025-04-16 21:08:00, Close 0.003176, KAMA nan, Prev Close 0.003191, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:09:00
# 检查交叉：时间 2025-04-16 21:09:00, Close 0.003132, KAMA nan, Prev Close 0.003176, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:10:00
# 检查交叉：时间 2025-04-16 21:10:00, Close 0.003194, KAMA nan, Prev Close 0.003132, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:11:00
# 检查交叉：时间 2025-04-16 21:11:00, Close 0.003248, KAMA nan, Prev Close 0.003194, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:12:00
# 检查交叉：时间 2025-04-16 21:12:00, Close 0.003176, KAMA nan, Prev Close 0.003248, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:13:00
# 检查交叉：时间 2025-04-16 21:13:00, Close 0.003154, KAMA nan, Prev Close 0.003176, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:14:00
# 检查交叉：时间 2025-04-16 21:14:00, Close 0.003108, KAMA nan, Prev Close 0.003154, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:15:00
# 检查交叉：时间 2025-04-16 21:15:00, Close 0.003084, KAMA nan, Prev Close 0.003108, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:16:00
# 检查交叉：时间 2025-04-16 21:16:00, Close 0.003091, KAMA nan, Prev Close 0.003084, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:17:00
# 检查交叉：时间 2025-04-16 21:17:00, Close 0.003093, KAMA nan, Prev Close 0.003091, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:18:00
# 检查交叉：时间 2025-04-16 21:18:00, Close 0.003130, KAMA nan, Prev Close 0.003093, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:19:00
# 检查交叉：时间 2025-04-16 21:19:00, Close 0.003144, KAMA nan, Prev Close 0.003130, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:20:00
# 检查交叉：时间 2025-04-16 21:20:00, Close 0.003122, KAMA nan, Prev Close 0.003144, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:21:00
# 检查交叉：时间 2025-04-16 21:21:00, Close 0.003059, KAMA nan, Prev Close 0.003122, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:22:00
# 检查交叉：时间 2025-04-16 21:22:00, Close 0.003085, KAMA nan, Prev Close 0.003059, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:23:00
# 检查交叉：时间 2025-04-16 21:23:00, Close 0.003121, KAMA nan, Prev Close 0.003085, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:24:00
# 检查交叉：时间 2025-04-16 21:24:00, Close 0.003159, KAMA nan, Prev Close 0.003121, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:25:00
# 检查交叉：时间 2025-04-16 21:25:00, Close 0.003180, KAMA nan, Prev Close 0.003159, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:26:00
# 检查交叉：时间 2025-04-16 21:26:00, Close 0.003315, KAMA nan, Prev Close 0.003180, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:27:00
# 检查交叉：时间 2025-04-16 21:27:00, Close 0.003329, KAMA nan, Prev Close 0.003315, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:28:00
# 检查交叉：时间 2025-04-16 21:28:00, Close 0.003284, KAMA nan, Prev Close 0.003329, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:29:00
# 检查交叉：时间 2025-04-16 21:29:00, Close 0.003294, KAMA nan, Prev Close 0.003284, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:30:00
# 检查交叉：时间 2025-04-16 21:30:00, Close 0.003248, KAMA nan, Prev Close 0.003294, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:31:00
# 检查交叉：时间 2025-04-16 21:31:00, Close 0.003194, KAMA nan, Prev Close 0.003248, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:32:00
# 检查交叉：时间 2025-04-16 21:32:00, Close 0.003201, KAMA nan, Prev Close 0.003194, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:33:00
# 检查交叉：时间 2025-04-16 21:33:00, Close 0.003250, KAMA nan, Prev Close 0.003201, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:34:00
# 检查交叉：时间 2025-04-16 21:34:00, Close 0.003376, KAMA nan, Prev Close 0.003250, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:35:00
# 检查交叉：时间 2025-04-16 21:35:00, Close 0.003367, KAMA nan, Prev Close 0.003376, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:36:00
# 检查交叉：时间 2025-04-16 21:36:00, Close 0.003254, KAMA nan, Prev Close 0.003367, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:37:00
# 检查交叉：时间 2025-04-16 21:37:00, Close 0.003334, KAMA nan, Prev Close 0.003254, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:38:00
# 检查交叉：时间 2025-04-16 21:38:00, Close 0.003289, KAMA nan, Prev Close 0.003334, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:39:00
# 检查交叉：时间 2025-04-16 21:39:00, Close 0.003254, KAMA nan, Prev Close 0.003289, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:40:00
# 检查交叉：时间 2025-04-16 21:40:00, Close 0.003224, KAMA nan, Prev Close 0.003254, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:41:00
# 检查交叉：时间 2025-04-16 21:41:00, Close 0.003223, KAMA nan, Prev Close 0.003224, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:42:00
# 检查交叉：时间 2025-04-16 21:42:00, Close 0.003197, KAMA nan, Prev Close 0.003223, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:43:00
# 检查交叉：时间 2025-04-16 21:43:00, Close 0.003117, KAMA nan, Prev Close 0.003197, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:44:00
# 检查交叉：时间 2025-04-16 21:44:00, Close 0.003182, KAMA nan, Prev Close 0.003117, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:45:00
# 检查交叉：时间 2025-04-16 21:45:00, Close 0.003270, KAMA nan, Prev Close 0.003182, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:46:00
# 检查交叉：时间 2025-04-16 21:46:00, Close 0.003254, KAMA nan, Prev Close 0.003270, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:47:00
# 检查交叉：时间 2025-04-16 21:47:00, Close 0.003312, KAMA nan, Prev Close 0.003254, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:48:00
# 检查交叉：时间 2025-04-16 21:48:00, Close 0.003257, KAMA nan, Prev Close 0.003312, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:49:00
# 检查交叉：时间 2025-04-16 21:49:00, Close 0.003229, KAMA nan, Prev Close 0.003257, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:50:00
# 检查交叉：时间 2025-04-16 21:50:00, Close 0.003279, KAMA nan, Prev Close 0.003229, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:51:00
# 检查交叉：时间 2025-04-16 21:51:00, Close 0.003310, KAMA nan, Prev Close 0.003279, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:52:00
# 检查交叉：时间 2025-04-16 21:52:00, Close 0.003396, KAMA nan, Prev Close 0.003310, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:53:00
# 检查交叉：时间 2025-04-16 21:53:00, Close 0.003284, KAMA nan, Prev Close 0.003396, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:54:00
# 检查交叉：时间 2025-04-16 21:54:00, Close 0.003250, KAMA nan, Prev Close 0.003284, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:55:00
# 检查交叉：时间 2025-04-16 21:55:00, Close 0.003213, KAMA nan, Prev Close 0.003250, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:56:00
# 检查交叉：时间 2025-04-16 21:56:00, Close 0.003237, KAMA nan, Prev Close 0.003213, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:57:00
# 检查交叉：时间 2025-04-16 21:57:00, Close 0.003249, KAMA nan, Prev Close 0.003237, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:58:00
# 检查交叉：时间 2025-04-16 21:58:00, Close 0.003282, KAMA nan, Prev Close 0.003249, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 21:59:00
# 检查交叉：时间 2025-04-16 21:59:00, Close 0.003275, KAMA nan, Prev Close 0.003282, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:00:00
# 检查交叉：时间 2025-04-16 22:00:00, Close 0.003337, KAMA nan, Prev Close 0.003275, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:01:00
# 检查交叉：时间 2025-04-16 22:01:00, Close 0.003380, KAMA nan, Prev Close 0.003337, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:02:00
# 检查交叉：时间 2025-04-16 22:02:00, Close 0.003410, KAMA nan, Prev Close 0.003380, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:03:00
# 检查交叉：时间 2025-04-16 22:03:00, Close 0.003323, KAMA nan, Prev Close 0.003410, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:04:00
# 检查交叉：时间 2025-04-16 22:04:00, Close 0.003318, KAMA nan, Prev Close 0.003323, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:05:00
# 检查交叉：时间 2025-04-16 22:05:00, Close 0.003288, KAMA nan, Prev Close 0.003318, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:06:00
# 检查交叉：时间 2025-04-16 22:06:00, Close 0.003269, KAMA nan, Prev Close 0.003288, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:07:00
# 检查交叉：时间 2025-04-16 22:07:00, Close 0.003347, KAMA nan, Prev Close 0.003269, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:08:00
# 检查交叉：时间 2025-04-16 22:08:00, Close 0.003469, KAMA nan, Prev Close 0.003347, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:09:00
# 检查交叉：时间 2025-04-16 22:09:00, Close 0.003446, KAMA nan, Prev Close 0.003469, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:10:00
# 检查交叉：时间 2025-04-16 22:10:00, Close 0.003511, KAMA nan, Prev Close 0.003446, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:11:00
# 检查交叉：时间 2025-04-16 22:11:00, Close 0.003453, KAMA nan, Prev Close 0.003511, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:12:00
# 检查交叉：时间 2025-04-16 22:12:00, Close 0.003407, KAMA nan, Prev Close 0.003453, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:13:00
# 检查交叉：时间 2025-04-16 22:13:00, Close 0.003380, KAMA nan, Prev Close 0.003407, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:14:00
# 检查交叉：时间 2025-04-16 22:14:00, Close 0.003375, KAMA nan, Prev Close 0.003380, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:15:00
# 检查交叉：时间 2025-04-16 22:15:00, Close 0.003368, KAMA nan, Prev Close 0.003375, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:16:00
# 检查交叉：时间 2025-04-16 22:16:00, Close 0.003361, KAMA nan, Prev Close 0.003368, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:17:00
# 检查交叉：时间 2025-04-16 22:17:00, Close 0.003307, KAMA nan, Prev Close 0.003361, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:18:00
# 检查交叉：时间 2025-04-16 22:18:00, Close 0.003315, KAMA nan, Prev Close 0.003307, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:19:00
# 检查交叉：时间 2025-04-16 22:19:00, Close 0.003316, KAMA nan, Prev Close 0.003315, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:20:00
# 检查交叉：时间 2025-04-16 22:20:00, Close 0.003278, KAMA nan, Prev Close 0.003316, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:21:00
# 检查交叉：时间 2025-04-16 22:21:00, Close 0.003307, KAMA nan, Prev Close 0.003278, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:22:00
# 检查交叉：时间 2025-04-16 22:22:00, Close 0.003360, KAMA nan, Prev Close 0.003307, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:23:00
# 检查交叉：时间 2025-04-16 22:23:00, Close 0.003425, KAMA nan, Prev Close 0.003360, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:24:00
# 检查交叉：时间 2025-04-16 22:24:00, Close 0.003401, KAMA nan, Prev Close 0.003425, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:25:00
# 检查交叉：时间 2025-04-16 22:25:00, Close 0.003345, KAMA nan, Prev Close 0.003401, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:26:00
# 检查交叉：时间 2025-04-16 22:26:00, Close 0.003350, KAMA nan, Prev Close 0.003345, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:27:00
# 检查交叉：时间 2025-04-16 22:27:00, Close 0.003300, KAMA nan, Prev Close 0.003350, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:28:00
# 检查交叉：时间 2025-04-16 22:28:00, Close 0.003324, KAMA nan, Prev Close 0.003300, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:29:00
# 检查交叉：时间 2025-04-16 22:29:00, Close 0.003352, KAMA nan, Prev Close 0.003324, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:30:00
# 检查交叉：时间 2025-04-16 22:30:00, Close 0.003326, KAMA nan, Prev Close 0.003352, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:31:00
# 检查交叉：时间 2025-04-16 22:31:00, Close 0.003314, KAMA nan, Prev Close 0.003326, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:32:00
# 检查交叉：时间 2025-04-16 22:32:00, Close 0.003314, KAMA nan, Prev Close 0.003314, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:33:00
# 检查交叉：时间 2025-04-16 22:33:00, Close 0.003371, KAMA nan, Prev Close 0.003314, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:34:00
# 检查交叉：时间 2025-04-16 22:34:00, Close 0.003320, KAMA nan, Prev Close 0.003371, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:35:00
# 检查交叉：时间 2025-04-16 22:35:00, Close 0.003347, KAMA nan, Prev Close 0.003320, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:36:00
# 检查交叉：时间 2025-04-16 22:36:00, Close 0.003325, KAMA nan, Prev Close 0.003347, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:37:00
# 检查交叉：时间 2025-04-16 22:37:00, Close 0.003183, KAMA nan, Prev Close 0.003325, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:38:00
# 检查交叉：时间 2025-04-16 22:38:00, Close 0.003116, KAMA nan, Prev Close 0.003183, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:39:00
# 检查交叉：时间 2025-04-16 22:39:00, Close 0.003114, KAMA nan, Prev Close 0.003116, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:40:00
# 检查交叉：时间 2025-04-16 22:40:00, Close 0.003124, KAMA nan, Prev Close 0.003114, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:41:00
# 检查交叉：时间 2025-04-16 22:41:00, Close 0.003091, KAMA nan, Prev Close 0.003124, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:42:00
# 检查交叉：时间 2025-04-16 22:42:00, Close 0.002988, KAMA nan, Prev Close 0.003091, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:43:00
# 检查交叉：时间 2025-04-16 22:43:00, Close 0.003083, KAMA nan, Prev Close 0.002988, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:44:00
# 检查交叉：时间 2025-04-16 22:44:00, Close 0.003034, KAMA nan, Prev Close 0.003083, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:45:00
# 检查交叉：时间 2025-04-16 22:45:00, Close 0.003109, KAMA nan, Prev Close 0.003034, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:46:00
# 检查交叉：时间 2025-04-16 22:46:00, Close 0.003138, KAMA nan, Prev Close 0.003109, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:47:00
# 检查交叉：时间 2025-04-16 22:47:00, Close 0.003221, KAMA nan, Prev Close 0.003138, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:48:00
# 检查交叉：时间 2025-04-16 22:48:00, Close 0.003296, KAMA nan, Prev Close 0.003221, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:49:00
# 检查交叉：时间 2025-04-16 22:49:00, Close 0.003348, KAMA nan, Prev Close 0.003296, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:50:00
# 检查交叉：时间 2025-04-16 22:50:00, Close 0.003410, KAMA nan, Prev Close 0.003348, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:51:00
# 检查交叉：时间 2025-04-16 22:51:00, Close 0.003367, KAMA nan, Prev Close 0.003410, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:52:00
# 检查交叉：时间 2025-04-16 22:52:00, Close 0.003381, KAMA nan, Prev Close 0.003367, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:53:00
# 检查交叉：时间 2025-04-16 22:53:00, Close 0.003400, KAMA nan, Prev Close 0.003381, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:54:00
# 检查交叉：时间 2025-04-16 22:54:00, Close 0.003424, KAMA nan, Prev Close 0.003400, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:55:00
# 检查交叉：时间 2025-04-16 22:55:00, Close 0.003449, KAMA nan, Prev Close 0.003424, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:56:00
# 检查交叉：时间 2025-04-16 22:56:00, Close 0.003474, KAMA nan, Prev Close 0.003449, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:57:00
# 检查交叉：时间 2025-04-16 22:57:00, Close 0.003527, KAMA nan, Prev Close 0.003474, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:58:00
# 检查交叉：时间 2025-04-16 22:58:00, Close 0.003523, KAMA nan, Prev Close 0.003527, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 22:59:00
# 检查交叉：时间 2025-04-16 22:59:00, Close 0.003538, KAMA nan, Prev Close 0.003523, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:00:00
# 检查交叉：时间 2025-04-16 23:00:00, Close 0.003520, KAMA nan, Prev Close 0.003538, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:01:00
# 检查交叉：时间 2025-04-16 23:01:00, Close 0.003534, KAMA nan, Prev Close 0.003520, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:02:00
# 检查交叉：时间 2025-04-16 23:02:00, Close 0.003497, KAMA nan, Prev Close 0.003534, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:03:00
# 检查交叉：时间 2025-04-16 23:03:00, Close 0.003467, KAMA nan, Prev Close 0.003497, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:04:00
# 检查交叉：时间 2025-04-16 23:04:00, Close 0.003458, KAMA nan, Prev Close 0.003467, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:05:00
# 检查交叉：时间 2025-04-16 23:05:00, Close 0.003507, KAMA nan, Prev Close 0.003458, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:06:00
# 检查交叉：时间 2025-04-16 23:06:00, Close 0.003532, KAMA nan, Prev Close 0.003507, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:07:00
# 检查交叉：时间 2025-04-16 23:07:00, Close 0.003590, KAMA nan, Prev Close 0.003532, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:08:00
# 检查交叉：时间 2025-04-16 23:08:00, Close 0.003578, KAMA nan, Prev Close 0.003590, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:09:00
# 检查交叉：时间 2025-04-16 23:09:00, Close 0.003620, KAMA nan, Prev Close 0.003578, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:10:00
# 检查交叉：时间 2025-04-16 23:10:00, Close 0.003598, KAMA nan, Prev Close 0.003620, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:11:00
# 检查交叉：时间 2025-04-16 23:11:00, Close 0.003554, KAMA nan, Prev Close 0.003598, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:12:00
# 检查交叉：时间 2025-04-16 23:12:00, Close 0.003455, KAMA nan, Prev Close 0.003554, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:13:00
# 检查交叉：时间 2025-04-16 23:13:00, Close 0.003549, KAMA nan, Prev Close 0.003455, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:14:00
# 检查交叉：时间 2025-04-16 23:14:00, Close 0.003589, KAMA nan, Prev Close 0.003549, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:15:00
# 检查交叉：时间 2025-04-16 23:15:00, Close 0.003501, KAMA nan, Prev Close 0.003589, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:16:00
# 检查交叉：时间 2025-04-16 23:16:00, Close 0.003536, KAMA nan, Prev Close 0.003501, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:17:00
# 检查交叉：时间 2025-04-16 23:17:00, Close 0.003630, KAMA nan, Prev Close 0.003536, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:18:00
# 检查交叉：时间 2025-04-16 23:18:00, Close 0.003692, KAMA nan, Prev Close 0.003630, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:19:00
# 检查交叉：时间 2025-04-16 23:19:00, Close 0.003630, KAMA nan, Prev Close 0.003692, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:20:00
# 检查交叉：时间 2025-04-16 23:20:00, Close 0.003648, KAMA nan, Prev Close 0.003630, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:21:00
# 检查交叉：时间 2025-04-16 23:21:00, Close 0.003691, KAMA nan, Prev Close 0.003648, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:22:00
# 检查交叉：时间 2025-04-16 23:22:00, Close 0.003650, KAMA nan, Prev Close 0.003691, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:23:00
# 检查交叉：时间 2025-04-16 23:23:00, Close 0.003670, KAMA nan, Prev Close 0.003650, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:24:00
# 检查交叉：时间 2025-04-16 23:24:00, Close 0.003652, KAMA nan, Prev Close 0.003670, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:25:00
# 检查交叉：时间 2025-04-16 23:25:00, Close 0.003580, KAMA nan, Prev Close 0.003652, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:26:00
# 检查交叉：时间 2025-04-16 23:26:00, Close 0.003558, KAMA nan, Prev Close 0.003580, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:27:00
# 检查交叉：时间 2025-04-16 23:27:00, Close 0.003540, KAMA nan, Prev Close 0.003558, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:28:00
# 检查交叉：时间 2025-04-16 23:28:00, Close 0.003463, KAMA nan, Prev Close 0.003540, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:29:00
# 检查交叉：时间 2025-04-16 23:29:00, Close 0.003477, KAMA nan, Prev Close 0.003463, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:30:00
# 检查交叉：时间 2025-04-16 23:30:00, Close 0.003517, KAMA nan, Prev Close 0.003477, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:31:00
# 检查交叉：时间 2025-04-16 23:31:00, Close 0.003557, KAMA nan, Prev Close 0.003517, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:32:00
# 检查交叉：时间 2025-04-16 23:32:00, Close 0.003624, KAMA nan, Prev Close 0.003557, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:33:00
# 检查交叉：时间 2025-04-16 23:33:00, Close 0.003640, KAMA nan, Prev Close 0.003624, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:34:00
# 检查交叉：时间 2025-04-16 23:34:00, Close 0.003586, KAMA nan, Prev Close 0.003640, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:35:00
# 检查交叉：时间 2025-04-16 23:35:00, Close 0.003565, KAMA nan, Prev Close 0.003586, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:36:00
# 检查交叉：时间 2025-04-16 23:36:00, Close 0.003497, KAMA nan, Prev Close 0.003565, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:37:00
# 检查交叉：时间 2025-04-16 23:37:00, Close 0.003513, KAMA nan, Prev Close 0.003497, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:38:00
# 检查交叉：时间 2025-04-16 23:38:00, Close 0.003486, KAMA nan, Prev Close 0.003513, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:39:00
# 检查交叉：时间 2025-04-16 23:39:00, Close 0.003466, KAMA nan, Prev Close 0.003486, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:40:00
# 检查交叉：时间 2025-04-16 23:40:00, Close 0.003491, KAMA nan, Prev Close 0.003466, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:41:00
# 检查交叉：时间 2025-04-16 23:41:00, Close 0.003502, KAMA nan, Prev Close 0.003491, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:42:00
# 检查交叉：时间 2025-04-16 23:42:00, Close 0.003592, KAMA nan, Prev Close 0.003502, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:43:00
# 检查交叉：时间 2025-04-16 23:43:00, Close 0.003512, KAMA nan, Prev Close 0.003592, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:44:00
# 检查交叉：时间 2025-04-16 23:44:00, Close 0.003449, KAMA nan, Prev Close 0.003512, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:45:00
# 检查交叉：时间 2025-04-16 23:45:00, Close 0.003469, KAMA nan, Prev Close 0.003449, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:46:00
# 检查交叉：时间 2025-04-16 23:46:00, Close 0.003541, KAMA nan, Prev Close 0.003469, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:47:00
# 检查交叉：时间 2025-04-16 23:47:00, Close 0.003548, KAMA nan, Prev Close 0.003541, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:48:00
# 检查交叉：时间 2025-04-16 23:48:00, Close 0.003543, KAMA nan, Prev Close 0.003548, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:49:00
# 检查交叉：时间 2025-04-16 23:49:00, Close 0.003564, KAMA nan, Prev Close 0.003543, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:50:00
# 检查交叉：时间 2025-04-16 23:50:00, Close 0.003597, KAMA nan, Prev Close 0.003564, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:51:00
# 检查交叉：时间 2025-04-16 23:51:00, Close 0.003613, KAMA nan, Prev Close 0.003597, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:52:00
# 检查交叉：时间 2025-04-16 23:52:00, Close 0.003608, KAMA nan, Prev Close 0.003613, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:53:00
# 检查交叉：时间 2025-04-16 23:53:00, Close 0.003464, KAMA nan, Prev Close 0.003608, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:54:00
# 检查交叉：时间 2025-04-16 23:54:00, Close 0.003520, KAMA nan, Prev Close 0.003464, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:55:00
# 检查交叉：时间 2025-04-16 23:55:00, Close 0.003578, KAMA nan, Prev Close 0.003520, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:56:00
# 检查交叉：时间 2025-04-16 23:56:00, Close 0.003554, KAMA nan, Prev Close 0.003578, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:57:00
# 检查交叉：时间 2025-04-16 23:57:00, Close 0.003636, KAMA nan, Prev Close 0.003554, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:58:00
# 检查交叉：时间 2025-04-16 23:58:00, Close 0.003720, KAMA nan, Prev Close 0.003636, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 23:59:00
# 检查交叉：时间 2025-04-16 23:59:00, Close 0.003628, KAMA nan, Prev Close 0.003720, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:00:00
# 检查交叉：时间 2025-04-17 00:00:00, Close 0.003642, KAMA nan, Prev Close 0.003628, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:01:00
# 检查交叉：时间 2025-04-17 00:01:00, Close 0.003594, KAMA nan, Prev Close 0.003642, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:02:00
# 检查交叉：时间 2025-04-17 00:02:00, Close 0.003563, KAMA nan, Prev Close 0.003594, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:03:00
# 检查交叉：时间 2025-04-17 00:03:00, Close 0.003578, KAMA nan, Prev Close 0.003563, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:04:00
# 检查交叉：时间 2025-04-17 00:04:00, Close 0.003631, KAMA nan, Prev Close 0.003578, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:05:00
# 检查交叉：时间 2025-04-17 00:05:00, Close 0.003550, KAMA nan, Prev Close 0.003631, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:06:00
# 检查交叉：时间 2025-04-17 00:06:00, Close 0.003583, KAMA nan, Prev Close 0.003550, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:07:00
# 检查交叉：时间 2025-04-17 00:07:00, Close 0.003516, KAMA nan, Prev Close 0.003583, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:08:00
# 检查交叉：时间 2025-04-17 00:08:00, Close 0.003623, KAMA nan, Prev Close 0.003516, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:09:00
# 检查交叉：时间 2025-04-17 00:09:00, Close 0.003629, KAMA nan, Prev Close 0.003623, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:10:00
# 检查交叉：时间 2025-04-17 00:10:00, Close 0.003616, KAMA nan, Prev Close 0.003629, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:11:00
# 检查交叉：时间 2025-04-17 00:11:00, Close 0.003605, KAMA nan, Prev Close 0.003616, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:12:00
# 检查交叉：时间 2025-04-17 00:12:00, Close 0.003504, KAMA nan, Prev Close 0.003605, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:13:00
# 检查交叉：时间 2025-04-17 00:13:00, Close 0.003536, KAMA nan, Prev Close 0.003504, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:14:00
# 检查交叉：时间 2025-04-17 00:14:00, Close 0.003580, KAMA nan, Prev Close 0.003536, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:15:00
# 检查交叉：时间 2025-04-17 00:15:00, Close 0.003453, KAMA nan, Prev Close 0.003580, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:16:00
# 检查交叉：时间 2025-04-17 00:16:00, Close 0.003429, KAMA nan, Prev Close 0.003453, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:17:00
# 检查交叉：时间 2025-04-17 00:17:00, Close 0.003468, KAMA nan, Prev Close 0.003429, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:18:00
# 检查交叉：时间 2025-04-17 00:18:00, Close 0.003497, KAMA nan, Prev Close 0.003468, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:19:00
# 检查交叉：时间 2025-04-17 00:19:00, Close 0.003646, KAMA nan, Prev Close 0.003497, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 00:20:00
# ...
# 检查交叉：时间 2025-04-17 02:52:00, Close 0.003572, KAMA nan, Prev Close 0.003634, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 02:53:00
# 检查交叉：时间 2025-04-17 02:53:00, Close 0.003514, KAMA nan, Prev Close 0.003572, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 02:54:00
# 检查交叉：时间 2025-04-17 02:54:00, Close 0.003533, KAMA nan, Prev Close 0.003514, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 02:55:00
# 检查交叉：时间 2025-04-17 02:55:00, Close 0.003587, KAMA nan, Prev Close 0.003533, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 02:56:00
# 检查交叉：时间 2025-04-17 02:56:00, Close 0.003608, KAMA nan, Prev Close 0.003587, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 02:57:00
# 检查交叉：时间 2025-04-17 02:57:00, Close 0.003625, KAMA nan, Prev Close 0.003608, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 02:58:00
# 检查交叉：时间 2025-04-17 02:58:00, Close 0.003641, KAMA nan, Prev Close 0.003625, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 02:59:00
# 检查交叉：时间 2025-04-17 02:59:00, Close 0.003670, KAMA nan, Prev Close 0.003641, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:00:00
# 检查交叉：时间 2025-04-17 03:00:00, Close 0.003550, KAMA nan, Prev Close 0.003670, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:01:00
# 检查交叉：时间 2025-04-17 03:01:00, Close 0.003549, KAMA nan, Prev Close 0.003550, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:02:00
# 检查交叉：时间 2025-04-17 03:02:00, Close 0.003597, KAMA nan, Prev Close 0.003549, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:03:00
# 检查交叉：时间 2025-04-17 03:03:00, Close 0.003615, KAMA nan, Prev Close 0.003597, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:04:00
# 检查交叉：时间 2025-04-17 03:04:00, Close 0.003685, KAMA nan, Prev Close 0.003615, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:05:00
# 检查交叉：时间 2025-04-17 03:05:00, Close 0.003633, KAMA nan, Prev Close 0.003685, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:06:00
# 检查交叉：时间 2025-04-17 03:06:00, Close 0.003594, KAMA nan, Prev Close 0.003633, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:07:00
# 检查交叉：时间 2025-04-17 03:07:00, Close 0.003582, KAMA nan, Prev Close 0.003594, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:08:00
# 检查交叉：时间 2025-04-17 03:08:00, Close 0.003624, KAMA nan, Prev Close 0.003582, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:09:00
# 检查交叉：时间 2025-04-17 03:09:00, Close 0.003700, KAMA nan, Prev Close 0.003624, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:10:00
# 检查交叉：时间 2025-04-17 03:10:00, Close 0.003851, KAMA nan, Prev Close 0.003700, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:11:00
# 检查交叉：时间 2025-04-17 03:11:00, Close 0.003872, KAMA nan, Prev Close 0.003851, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:12:00
# 检查交叉：时间 2025-04-17 03:12:00, Close 0.003863, KAMA nan, Prev Close 0.003872, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:13:00
# 检查交叉：时间 2025-04-17 03:13:00, Close 0.003969, KAMA nan, Prev Close 0.003863, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:14:00
# 检查交叉：时间 2025-04-17 03:14:00, Close 0.003901, KAMA nan, Prev Close 0.003969, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:15:00
# 检查交叉：时间 2025-04-17 03:15:00, Close 0.003853, KAMA nan, Prev Close 0.003901, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:16:00
# 检查交叉：时间 2025-04-17 03:16:00, Close 0.003906, KAMA nan, Prev Close 0.003853, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:17:00
# 检查交叉：时间 2025-04-17 03:17:00, Close 0.003883, KAMA nan, Prev Close 0.003906, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:18:00
# 检查交叉：时间 2025-04-17 03:18:00, Close 0.003831, KAMA nan, Prev Close 0.003883, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:19:00
# 检查交叉：时间 2025-04-17 03:19:00, Close 0.003844, KAMA nan, Prev Close 0.003831, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:20:00
# 检查交叉：时间 2025-04-17 03:20:00, Close 0.003839, KAMA nan, Prev Close 0.003844, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:21:00
# 检查交叉：时间 2025-04-17 03:21:00, Close 0.003895, KAMA nan, Prev Close 0.003839, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:22:00
# 检查交叉：时间 2025-04-17 03:22:00, Close 0.003955, KAMA nan, Prev Close 0.003895, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:23:00
# 检查交叉：时间 2025-04-17 03:23:00, Close 0.003963, KAMA nan, Prev Close 0.003955, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:24:00
# 检查交叉：时间 2025-04-17 03:24:00, Close 0.004051, KAMA nan, Prev Close 0.003963, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:25:00
# 检查交叉：时间 2025-04-17 03:25:00, Close 0.003934, KAMA nan, Prev Close 0.004051, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:26:00
# 检查交叉：时间 2025-04-17 03:26:00, Close 0.004117, KAMA nan, Prev Close 0.003934, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:27:00
# 检查交叉：时间 2025-04-17 03:27:00, Close 0.004145, KAMA nan, Prev Close 0.004117, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:28:00
# 检查交叉：时间 2025-04-17 03:28:00, Close 0.004104, KAMA nan, Prev Close 0.004145, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:29:00
# 检查交叉：时间 2025-04-17 03:29:00, Close 0.004024, KAMA nan, Prev Close 0.004104, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:30:00
# 检查交叉：时间 2025-04-17 03:30:00, Close 0.003984, KAMA nan, Prev Close 0.004024, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:31:00
# 检查交叉：时间 2025-04-17 03:31:00, Close 0.004101, KAMA nan, Prev Close 0.003984, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:32:00
# 检查交叉：时间 2025-04-17 03:32:00, Close 0.004057, KAMA nan, Prev Close 0.004101, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:33:00
# 检查交叉：时间 2025-04-17 03:33:00, Close 0.004043, KAMA nan, Prev Close 0.004057, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:34:00
# 检查交叉：时间 2025-04-17 03:34:00, Close 0.003928, KAMA nan, Prev Close 0.004043, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:35:00
# 检查交叉：时间 2025-04-17 03:35:00, Close 0.003969, KAMA nan, Prev Close 0.003928, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:36:00
# 检查交叉：时间 2025-04-17 03:36:00, Close 0.004039, KAMA nan, Prev Close 0.003969, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:37:00
# 检查交叉：时间 2025-04-17 03:37:00, Close 0.004178, KAMA nan, Prev Close 0.004039, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:38:00
# 检查交叉：时间 2025-04-17 03:38:00, Close 0.004341, KAMA nan, Prev Close 0.004178, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:39:00
# 检查交叉：时间 2025-04-17 03:39:00, Close 0.004329, KAMA nan, Prev Close 0.004341, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:40:00
# 检查交叉：时间 2025-04-17 03:40:00, Close 0.004242, KAMA nan, Prev Close 0.004329, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:41:00
# 检查交叉：时间 2025-04-17 03:41:00, Close 0.004189, KAMA nan, Prev Close 0.004242, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:42:00
# 检查交叉：时间 2025-04-17 03:42:00, Close 0.004190, KAMA nan, Prev Close 0.004189, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:43:00
# 检查交叉：时间 2025-04-17 03:43:00, Close 0.004177, KAMA nan, Prev Close 0.004190, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:44:00
# 检查交叉：时间 2025-04-17 03:44:00, Close 0.004095, KAMA nan, Prev Close 0.004177, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:45:00
# 检查交叉：时间 2025-04-17 03:45:00, Close 0.003992, KAMA nan, Prev Close 0.004095, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:46:00
# 检查交叉：时间 2025-04-17 03:46:00, Close 0.004081, KAMA nan, Prev Close 0.003992, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:47:00
# 检查交叉：时间 2025-04-17 03:47:00, Close 0.004125, KAMA nan, Prev Close 0.004081, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:48:00
# 检查交叉：时间 2025-04-17 03:48:00, Close 0.004062, KAMA nan, Prev Close 0.004125, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:49:00
# 检查交叉：时间 2025-04-17 03:49:00, Close 0.004071, KAMA nan, Prev Close 0.004062, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:50:00
# 检查交叉：时间 2025-04-17 03:50:00, Close 0.004048, KAMA nan, Prev Close 0.004071, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:51:00
# 检查交叉：时间 2025-04-17 03:51:00, Close 0.004062, KAMA nan, Prev Close 0.004048, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:52:00
# 检查交叉：时间 2025-04-17 03:52:00, Close 0.004101, KAMA nan, Prev Close 0.004062, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:53:00
# 检查交叉：时间 2025-04-17 03:53:00, Close 0.004178, KAMA nan, Prev Close 0.004101, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:54:00
# 检查交叉：时间 2025-04-17 03:54:00, Close 0.004253, KAMA nan, Prev Close 0.004178, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:55:00
# 检查交叉：时间 2025-04-17 03:55:00, Close 0.004413, KAMA nan, Prev Close 0.004253, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:56:00
# 检查交叉：时间 2025-04-17 03:56:00, Close 0.004457, KAMA nan, Prev Close 0.004413, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:57:00
# 检查交叉：时间 2025-04-17 03:57:00, Close 0.004495, KAMA nan, Prev Close 0.004457, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:58:00
# 检查交叉：时间 2025-04-17 03:58:00, Close 0.004416, KAMA nan, Prev Close 0.004495, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 03:59:00
# 检查交叉：时间 2025-04-17 03:59:00, Close 0.004446, KAMA nan, Prev Close 0.004416, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:00:00
# 检查交叉：时间 2025-04-17 04:00:00, Close 0.004390, KAMA nan, Prev Close 0.004446, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:01:00
# 检查交叉：时间 2025-04-17 04:01:00, Close 0.004341, KAMA nan, Prev Close 0.004390, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:02:00
# 检查交叉：时间 2025-04-17 04:02:00, Close 0.004432, KAMA nan, Prev Close 0.004341, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:03:00
# 检查交叉：时间 2025-04-17 04:03:00, Close 0.004465, KAMA nan, Prev Close 0.004432, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:04:00
# 检查交叉：时间 2025-04-17 04:04:00, Close 0.004526, KAMA nan, Prev Close 0.004465, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:05:00
# 检查交叉：时间 2025-04-17 04:05:00, Close 0.004421, KAMA nan, Prev Close 0.004526, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:06:00
# 检查交叉：时间 2025-04-17 04:06:00, Close 0.004315, KAMA nan, Prev Close 0.004421, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:07:00
# 检查交叉：时间 2025-04-17 04:07:00, Close 0.004305, KAMA nan, Prev Close 0.004315, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:08:00
# 检查交叉：时间 2025-04-17 04:08:00, Close 0.004285, KAMA nan, Prev Close 0.004305, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:09:00
# 检查交叉：时间 2025-04-17 04:09:00, Close 0.004258, KAMA nan, Prev Close 0.004285, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:10:00
# 检查交叉：时间 2025-04-17 04:10:00, Close 0.004258, KAMA nan, Prev Close 0.004258, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:11:00
# 检查交叉：时间 2025-04-17 04:11:00, Close 0.004220, KAMA nan, Prev Close 0.004258, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:12:00
# 检查交叉：时间 2025-04-17 04:12:00, Close 0.004196, KAMA nan, Prev Close 0.004220, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:13:00
# 检查交叉：时间 2025-04-17 04:13:00, Close 0.004189, KAMA nan, Prev Close 0.004196, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:14:00
# 检查交叉：时间 2025-04-17 04:14:00, Close 0.004086, KAMA nan, Prev Close 0.004189, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:15:00
# 检查交叉：时间 2025-04-17 04:15:00, Close 0.004052, KAMA nan, Prev Close 0.004086, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:16:00
# 检查交叉：时间 2025-04-17 04:16:00, Close 0.004049, KAMA nan, Prev Close 0.004052, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:17:00
# 检查交叉：时间 2025-04-17 04:17:00, Close 0.004000, KAMA nan, Prev Close 0.004049, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:18:00
# 检查交叉：时间 2025-04-17 04:18:00, Close 0.003839, KAMA nan, Prev Close 0.004000, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:19:00
# 检查交叉：时间 2025-04-17 04:19:00, Close 0.003895, KAMA nan, Prev Close 0.003839, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:20:00
# 检查交叉：时间 2025-04-17 04:20:00, Close 0.003852, KAMA nan, Prev Close 0.003895, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:21:00
# 检查交叉：时间 2025-04-17 04:21:00, Close 0.003842, KAMA nan, Prev Close 0.003852, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:22:00
# 检查交叉：时间 2025-04-17 04:22:00, Close 0.003864, KAMA nan, Prev Close 0.003842, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:23:00
# 检查交叉：时间 2025-04-17 04:23:00, Close 0.003752, KAMA nan, Prev Close 0.003864, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:24:00
# 检查交叉：时间 2025-04-17 04:24:00, Close 0.003755, KAMA nan, Prev Close 0.003752, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:25:00
# 检查交叉：时间 2025-04-17 04:25:00, Close 0.003766, KAMA nan, Prev Close 0.003755, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:26:00
# 检查交叉：时间 2025-04-17 04:26:00, Close 0.003828, KAMA nan, Prev Close 0.003766, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:27:00
# 检查交叉：时间 2025-04-17 04:27:00, Close 0.003831, KAMA nan, Prev Close 0.003828, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:28:00
# 检查交叉：时间 2025-04-17 04:28:00, Close 0.003815, KAMA nan, Prev Close 0.003831, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:29:00
# 检查交叉：时间 2025-04-17 04:29:00, Close 0.003780, KAMA nan, Prev Close 0.003815, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:30:00
# 检查交叉：时间 2025-04-17 04:30:00, Close 0.003821, KAMA nan, Prev Close 0.003780, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:31:00
# 检查交叉：时间 2025-04-17 04:31:00, Close 0.003820, KAMA nan, Prev Close 0.003821, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:32:00
# 检查交叉：时间 2025-04-17 04:32:00, Close 0.003789, KAMA nan, Prev Close 0.003820, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:33:00
# 检查交叉：时间 2025-04-17 04:33:00, Close 0.003826, KAMA nan, Prev Close 0.003789, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:34:00
# 检查交叉：时间 2025-04-17 04:34:00, Close 0.003762, KAMA nan, Prev Close 0.003826, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:35:00
# 检查交叉：时间 2025-04-17 04:35:00, Close 0.003675, KAMA nan, Prev Close 0.003762, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:36:00
# 检查交叉：时间 2025-04-17 04:36:00, Close 0.003780, KAMA nan, Prev Close 0.003675, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:37:00
# 检查交叉：时间 2025-04-17 04:37:00, Close 0.003837, KAMA nan, Prev Close 0.003780, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:38:00
# 检查交叉：时间 2025-04-17 04:38:00, Close 0.003891, KAMA nan, Prev Close 0.003837, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:39:00
# 检查交叉：时间 2025-04-17 04:39:00, Close 0.003849, KAMA nan, Prev Close 0.003891, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:40:00
# 检查交叉：时间 2025-04-17 04:40:00, Close 0.003845, KAMA nan, Prev Close 0.003849, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:41:00
# 检查交叉：时间 2025-04-17 04:41:00, Close 0.003917, KAMA nan, Prev Close 0.003845, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:42:00
# 检查交叉：时间 2025-04-17 04:42:00, Close 0.003918, KAMA nan, Prev Close 0.003917, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-17 04:43:00
# 检查交叉：时间 2025-04-17 04:43:00, Close 0.003828, KAMA nan, Prev Close 0.003918, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 回测完成：交易次数 0

# %%
# Out:
# 成功导入 KAMAStrategy 和 RSIStrategy
# 加载数据：600 条，时间范围：2025-04-16 05:18:00 到 2025-04-16 15:17:00
# 价格范围：open 0.00316723 - 0.00582175, close 0.00316723 - 0.00582175
# 执行 next：时间 2025-04-16 05:20:00
# 检查交叉：时间 2025-04-16 05:20:00, Close 0.004310, KAMA nan, Prev Close 0.004365, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:21:00
# 检查交叉：时间 2025-04-16 05:21:00, Close 0.004403, KAMA nan, Prev Close 0.004310, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:22:00
# 检查交叉：时间 2025-04-16 05:22:00, Close 0.004378, KAMA nan, Prev Close 0.004403, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:23:00
# 检查交叉：时间 2025-04-16 05:23:00, Close 0.004406, KAMA nan, Prev Close 0.004378, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:24:00
# 检查交叉：时间 2025-04-16 05:24:00, Close 0.004498, KAMA nan, Prev Close 0.004406, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:25:00
# 检查交叉：时间 2025-04-16 05:25:00, Close 0.004533, KAMA nan, Prev Close 0.004498, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:26:00
# 检查交叉：时间 2025-04-16 05:26:00, Close 0.004533, KAMA nan, Prev Close 0.004533, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:27:00
# 检查交叉：时间 2025-04-16 05:27:00, Close 0.004643, KAMA nan, Prev Close 0.004533, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:28:00
# 检查交叉：时间 2025-04-16 05:28:00, Close 0.004763, KAMA nan, Prev Close 0.004643, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:29:00
# 检查交叉：时间 2025-04-16 05:29:00, Close 0.004741, KAMA nan, Prev Close 0.004763, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:30:00
# 检查交叉：时间 2025-04-16 05:30:00, Close 0.004648, KAMA nan, Prev Close 0.004741, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:31:00
# 检查交叉：时间 2025-04-16 05:31:00, Close 0.004707, KAMA nan, Prev Close 0.004648, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:32:00
# 检查交叉：时间 2025-04-16 05:32:00, Close 0.004664, KAMA nan, Prev Close 0.004707, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:33:00
# 检查交叉：时间 2025-04-16 05:33:00, Close 0.004680, KAMA nan, Prev Close 0.004664, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:34:00
# 检查交叉：时间 2025-04-16 05:34:00, Close 0.004581, KAMA nan, Prev Close 0.004680, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:35:00
# 检查交叉：时间 2025-04-16 05:35:00, Close 0.004614, KAMA nan, Prev Close 0.004581, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:36:00
# 检查交叉：时间 2025-04-16 05:36:00, Close 0.004603, KAMA nan, Prev Close 0.004614, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:37:00
# 检查交叉：时间 2025-04-16 05:37:00, Close 0.004585, KAMA nan, Prev Close 0.004603, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:38:00
# 检查交叉：时间 2025-04-16 05:38:00, Close 0.004566, KAMA nan, Prev Close 0.004585, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:39:00
# 检查交叉：时间 2025-04-16 05:39:00, Close 0.004561, KAMA nan, Prev Close 0.004566, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:40:00
# 检查交叉：时间 2025-04-16 05:40:00, Close 0.004585, KAMA nan, Prev Close 0.004561, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:41:00
# 检查交叉：时间 2025-04-16 05:41:00, Close 0.004656, KAMA nan, Prev Close 0.004585, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:42:00
# 检查交叉：时间 2025-04-16 05:42:00, Close 0.004663, KAMA nan, Prev Close 0.004656, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:43:00
# 检查交叉：时间 2025-04-16 05:43:00, Close 0.004673, KAMA nan, Prev Close 0.004663, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:44:00
# 检查交叉：时间 2025-04-16 05:44:00, Close 0.004773, KAMA nan, Prev Close 0.004673, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:45:00
# 检查交叉：时间 2025-04-16 05:45:00, Close 0.004829, KAMA nan, Prev Close 0.004773, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:46:00
# 检查交叉：时间 2025-04-16 05:46:00, Close 0.004741, KAMA nan, Prev Close 0.004829, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:47:00
# 检查交叉：时间 2025-04-16 05:47:00, Close 0.004776, KAMA nan, Prev Close 0.004741, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:48:00
# 检查交叉：时间 2025-04-16 05:48:00, Close 0.004777, KAMA nan, Prev Close 0.004776, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:49:00
# 检查交叉：时间 2025-04-16 05:49:00, Close 0.004742, KAMA nan, Prev Close 0.004777, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:50:00
# 检查交叉：时间 2025-04-16 05:50:00, Close 0.004808, KAMA nan, Prev Close 0.004742, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:51:00
# 检查交叉：时间 2025-04-16 05:51:00, Close 0.004694, KAMA nan, Prev Close 0.004808, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:52:00
# 检查交叉：时间 2025-04-16 05:52:00, Close 0.004665, KAMA nan, Prev Close 0.004694, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:53:00
# 检查交叉：时间 2025-04-16 05:53:00, Close 0.004704, KAMA nan, Prev Close 0.004665, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:54:00
# 检查交叉：时间 2025-04-16 05:54:00, Close 0.004664, KAMA nan, Prev Close 0.004704, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:55:00
# 检查交叉：时间 2025-04-16 05:55:00, Close 0.004674, KAMA nan, Prev Close 0.004664, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:56:00
# 检查交叉：时间 2025-04-16 05:56:00, Close 0.004699, KAMA nan, Prev Close 0.004674, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:57:00
# 检查交叉：时间 2025-04-16 05:57:00, Close 0.004668, KAMA nan, Prev Close 0.004699, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:58:00
# 检查交叉：时间 2025-04-16 05:58:00, Close 0.004707, KAMA nan, Prev Close 0.004668, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 05:59:00
# 检查交叉：时间 2025-04-16 05:59:00, Close 0.004687, KAMA nan, Prev Close 0.004707, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:00:00
# 检查交叉：时间 2025-04-16 06:00:00, Close 0.004708, KAMA nan, Prev Close 0.004687, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:01:00
# 检查交叉：时间 2025-04-16 06:01:00, Close 0.004688, KAMA nan, Prev Close 0.004708, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:02:00
# 检查交叉：时间 2025-04-16 06:02:00, Close 0.004644, KAMA nan, Prev Close 0.004688, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:03:00
# 检查交叉：时间 2025-04-16 06:03:00, Close 0.004638, KAMA nan, Prev Close 0.004644, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:04:00
# 检查交叉：时间 2025-04-16 06:04:00, Close 0.004536, KAMA nan, Prev Close 0.004638, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:05:00
# 检查交叉：时间 2025-04-16 06:05:00, Close 0.004414, KAMA nan, Prev Close 0.004536, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:06:00
# 检查交叉：时间 2025-04-16 06:06:00, Close 0.004468, KAMA nan, Prev Close 0.004414, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:07:00
# 检查交叉：时间 2025-04-16 06:07:00, Close 0.004442, KAMA nan, Prev Close 0.004468, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:08:00
# 检查交叉：时间 2025-04-16 06:08:00, Close 0.004423, KAMA nan, Prev Close 0.004442, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:09:00
# 检查交叉：时间 2025-04-16 06:09:00, Close 0.004452, KAMA nan, Prev Close 0.004423, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:10:00
# 检查交叉：时间 2025-04-16 06:10:00, Close 0.004469, KAMA nan, Prev Close 0.004452, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:11:00
# 检查交叉：时间 2025-04-16 06:11:00, Close 0.004455, KAMA nan, Prev Close 0.004469, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:12:00
# 检查交叉：时间 2025-04-16 06:12:00, Close 0.004403, KAMA nan, Prev Close 0.004455, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:13:00
# 检查交叉：时间 2025-04-16 06:13:00, Close 0.004483, KAMA nan, Prev Close 0.004403, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:14:00
# 检查交叉：时间 2025-04-16 06:14:00, Close 0.004482, KAMA nan, Prev Close 0.004483, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:15:00
# 检查交叉：时间 2025-04-16 06:15:00, Close 0.004548, KAMA nan, Prev Close 0.004482, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:16:00
# 检查交叉：时间 2025-04-16 06:16:00, Close 0.004614, KAMA nan, Prev Close 0.004548, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:17:00
# 检查交叉：时间 2025-04-16 06:17:00, Close 0.004586, KAMA nan, Prev Close 0.004614, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:18:00
# 检查交叉：时间 2025-04-16 06:18:00, Close 0.004528, KAMA nan, Prev Close 0.004586, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:19:00
# 检查交叉：时间 2025-04-16 06:19:00, Close 0.004576, KAMA nan, Prev Close 0.004528, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:20:00
# 检查交叉：时间 2025-04-16 06:20:00, Close 0.004566, KAMA nan, Prev Close 0.004576, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:21:00
# 检查交叉：时间 2025-04-16 06:21:00, Close 0.004574, KAMA nan, Prev Close 0.004566, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:22:00
# 检查交叉：时间 2025-04-16 06:22:00, Close 0.004636, KAMA nan, Prev Close 0.004574, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:23:00
# 检查交叉：时间 2025-04-16 06:23:00, Close 0.004558, KAMA nan, Prev Close 0.004636, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:24:00
# 检查交叉：时间 2025-04-16 06:24:00, Close 0.004729, KAMA nan, Prev Close 0.004558, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:25:00
# 检查交叉：时间 2025-04-16 06:25:00, Close 0.004791, KAMA nan, Prev Close 0.004729, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:26:00
# 检查交叉：时间 2025-04-16 06:26:00, Close 0.004774, KAMA nan, Prev Close 0.004791, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:27:00
# 检查交叉：时间 2025-04-16 06:27:00, Close 0.004723, KAMA nan, Prev Close 0.004774, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:28:00
# 检查交叉：时间 2025-04-16 06:28:00, Close 0.004805, KAMA nan, Prev Close 0.004723, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:29:00
# 检查交叉：时间 2025-04-16 06:29:00, Close 0.004759, KAMA nan, Prev Close 0.004805, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:30:00
# 检查交叉：时间 2025-04-16 06:30:00, Close 0.004789, KAMA nan, Prev Close 0.004759, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:31:00
# 检查交叉：时间 2025-04-16 06:31:00, Close 0.004757, KAMA nan, Prev Close 0.004789, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:32:00
# 检查交叉：时间 2025-04-16 06:32:00, Close 0.004718, KAMA nan, Prev Close 0.004757, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:33:00
# 检查交叉：时间 2025-04-16 06:33:00, Close 0.004655, KAMA nan, Prev Close 0.004718, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:34:00
# 检查交叉：时间 2025-04-16 06:34:00, Close 0.004614, KAMA nan, Prev Close 0.004655, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:35:00
# 检查交叉：时间 2025-04-16 06:35:00, Close 0.004562, KAMA nan, Prev Close 0.004614, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:36:00
# 检查交叉：时间 2025-04-16 06:36:00, Close 0.004636, KAMA nan, Prev Close 0.004562, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:37:00
# 检查交叉：时间 2025-04-16 06:37:00, Close 0.004644, KAMA nan, Prev Close 0.004636, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:38:00
# 检查交叉：时间 2025-04-16 06:38:00, Close 0.004671, KAMA nan, Prev Close 0.004644, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:39:00
# 检查交叉：时间 2025-04-16 06:39:00, Close 0.004768, KAMA nan, Prev Close 0.004671, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:40:00
# 检查交叉：时间 2025-04-16 06:40:00, Close 0.004883, KAMA nan, Prev Close 0.004768, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:41:00
# 检查交叉：时间 2025-04-16 06:41:00, Close 0.004814, KAMA nan, Prev Close 0.004883, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:42:00
# 检查交叉：时间 2025-04-16 06:42:00, Close 0.004639, KAMA nan, Prev Close 0.004814, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:43:00
# 检查交叉：时间 2025-04-16 06:43:00, Close 0.004642, KAMA nan, Prev Close 0.004639, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:44:00
# 检查交叉：时间 2025-04-16 06:44:00, Close 0.004380, KAMA nan, Prev Close 0.004642, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:45:00
# 检查交叉：时间 2025-04-16 06:45:00, Close 0.004254, KAMA nan, Prev Close 0.004380, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:46:00
# 检查交叉：时间 2025-04-16 06:46:00, Close 0.004145, KAMA nan, Prev Close 0.004254, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:47:00
# 检查交叉：时间 2025-04-16 06:47:00, Close 0.004082, KAMA nan, Prev Close 0.004145, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:48:00
# 检查交叉：时间 2025-04-16 06:48:00, Close 0.004043, KAMA nan, Prev Close 0.004082, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:49:00
# 检查交叉：时间 2025-04-16 06:49:00, Close 0.004048, KAMA nan, Prev Close 0.004043, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:50:00
# 检查交叉：时间 2025-04-16 06:50:00, Close 0.003985, KAMA nan, Prev Close 0.004048, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:51:00
# 检查交叉：时间 2025-04-16 06:51:00, Close 0.003891, KAMA nan, Prev Close 0.003985, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:52:00
# 检查交叉：时间 2025-04-16 06:52:00, Close 0.003928, KAMA nan, Prev Close 0.003891, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:53:00
# 检查交叉：时间 2025-04-16 06:53:00, Close 0.003945, KAMA nan, Prev Close 0.003928, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:54:00
# 检查交叉：时间 2025-04-16 06:54:00, Close 0.003913, KAMA nan, Prev Close 0.003945, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:55:00
# 检查交叉：时间 2025-04-16 06:55:00, Close 0.003903, KAMA nan, Prev Close 0.003913, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:56:00
# 检查交叉：时间 2025-04-16 06:56:00, Close 0.003843, KAMA nan, Prev Close 0.003903, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:57:00
# 检查交叉：时间 2025-04-16 06:57:00, Close 0.003862, KAMA nan, Prev Close 0.003843, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:58:00
# 检查交叉：时间 2025-04-16 06:58:00, Close 0.003855, KAMA nan, Prev Close 0.003862, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 06:59:00
# 检查交叉：时间 2025-04-16 06:59:00, Close 0.003787, KAMA nan, Prev Close 0.003855, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:00:00
# 检查交叉：时间 2025-04-16 07:00:00, Close 0.003754, KAMA nan, Prev Close 0.003787, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:01:00
# 检查交叉：时间 2025-04-16 07:01:00, Close 0.003789, KAMA nan, Prev Close 0.003754, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:02:00
# 检查交叉：时间 2025-04-16 07:02:00, Close 0.003829, KAMA nan, Prev Close 0.003789, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:03:00
# 检查交叉：时间 2025-04-16 07:03:00, Close 0.003819, KAMA nan, Prev Close 0.003829, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:04:00
# 检查交叉：时间 2025-04-16 07:04:00, Close 0.003831, KAMA nan, Prev Close 0.003819, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:05:00
# 检查交叉：时间 2025-04-16 07:05:00, Close 0.003855, KAMA nan, Prev Close 0.003831, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:06:00
# 检查交叉：时间 2025-04-16 07:06:00, Close 0.003828, KAMA nan, Prev Close 0.003855, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:07:00
# 检查交叉：时间 2025-04-16 07:07:00, Close 0.003787, KAMA nan, Prev Close 0.003828, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:08:00
# 检查交叉：时间 2025-04-16 07:08:00, Close 0.003850, KAMA nan, Prev Close 0.003787, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:09:00
# 检查交叉：时间 2025-04-16 07:09:00, Close 0.003923, KAMA nan, Prev Close 0.003850, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:10:00
# 检查交叉：时间 2025-04-16 07:10:00, Close 0.004000, KAMA nan, Prev Close 0.003923, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:11:00
# 检查交叉：时间 2025-04-16 07:11:00, Close 0.003969, KAMA nan, Prev Close 0.004000, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:12:00
# 检查交叉：时间 2025-04-16 07:12:00, Close 0.003946, KAMA nan, Prev Close 0.003969, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:13:00
# 检查交叉：时间 2025-04-16 07:13:00, Close 0.003917, KAMA nan, Prev Close 0.003946, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:14:00
# 检查交叉：时间 2025-04-16 07:14:00, Close 0.003912, KAMA nan, Prev Close 0.003917, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:15:00
# 检查交叉：时间 2025-04-16 07:15:00, Close 0.003891, KAMA nan, Prev Close 0.003912, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:16:00
# 检查交叉：时间 2025-04-16 07:16:00, Close 0.003930, KAMA nan, Prev Close 0.003891, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:17:00
# 检查交叉：时间 2025-04-16 07:17:00, Close 0.003995, KAMA nan, Prev Close 0.003930, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:18:00
# 检查交叉：时间 2025-04-16 07:18:00, Close 0.003930, KAMA nan, Prev Close 0.003995, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:19:00
# 检查交叉：时间 2025-04-16 07:19:00, Close 0.003941, KAMA nan, Prev Close 0.003930, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:20:00
# 检查交叉：时间 2025-04-16 07:20:00, Close 0.003857, KAMA nan, Prev Close 0.003941, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:21:00
# 检查交叉：时间 2025-04-16 07:21:00, Close 0.003930, KAMA nan, Prev Close 0.003857, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:22:00
# 检查交叉：时间 2025-04-16 07:22:00, Close 0.003932, KAMA nan, Prev Close 0.003930, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:23:00
# 检查交叉：时间 2025-04-16 07:23:00, Close 0.003899, KAMA nan, Prev Close 0.003932, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:24:00
# 检查交叉：时间 2025-04-16 07:24:00, Close 0.003907, KAMA nan, Prev Close 0.003899, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:25:00
# 检查交叉：时间 2025-04-16 07:25:00, Close 0.003926, KAMA nan, Prev Close 0.003907, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:26:00
# 检查交叉：时间 2025-04-16 07:26:00, Close 0.003875, KAMA nan, Prev Close 0.003926, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:27:00
# 检查交叉：时间 2025-04-16 07:27:00, Close 0.003903, KAMA nan, Prev Close 0.003875, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:28:00
# 检查交叉：时间 2025-04-16 07:28:00, Close 0.003769, KAMA nan, Prev Close 0.003903, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:29:00
# 检查交叉：时间 2025-04-16 07:29:00, Close 0.003697, KAMA nan, Prev Close 0.003769, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:30:00
# 检查交叉：时间 2025-04-16 07:30:00, Close 0.003734, KAMA nan, Prev Close 0.003697, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:31:00
# 检查交叉：时间 2025-04-16 07:31:00, Close 0.003671, KAMA nan, Prev Close 0.003734, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:32:00
# 检查交叉：时间 2025-04-16 07:32:00, Close 0.003780, KAMA nan, Prev Close 0.003671, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:33:00
# 检查交叉：时间 2025-04-16 07:33:00, Close 0.003838, KAMA nan, Prev Close 0.003780, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:34:00
# 检查交叉：时间 2025-04-16 07:34:00, Close 0.003993, KAMA nan, Prev Close 0.003838, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:35:00
# 检查交叉：时间 2025-04-16 07:35:00, Close 0.004088, KAMA nan, Prev Close 0.003993, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:36:00
# 检查交叉：时间 2025-04-16 07:36:00, Close 0.004069, KAMA nan, Prev Close 0.004088, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:37:00
# 检查交叉：时间 2025-04-16 07:37:00, Close 0.004041, KAMA nan, Prev Close 0.004069, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:38:00
# 检查交叉：时间 2025-04-16 07:38:00, Close 0.004031, KAMA nan, Prev Close 0.004041, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:39:00
# 检查交叉：时间 2025-04-16 07:39:00, Close 0.003944, KAMA nan, Prev Close 0.004031, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:40:00
# 检查交叉：时间 2025-04-16 07:40:00, Close 0.004039, KAMA nan, Prev Close 0.003944, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:41:00
# 检查交叉：时间 2025-04-16 07:41:00, Close 0.003972, KAMA nan, Prev Close 0.004039, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:42:00
# 检查交叉：时间 2025-04-16 07:42:00, Close 0.003989, KAMA nan, Prev Close 0.003972, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:43:00
# 检查交叉：时间 2025-04-16 07:43:00, Close 0.004097, KAMA nan, Prev Close 0.003989, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:44:00
# 检查交叉：时间 2025-04-16 07:44:00, Close 0.003989, KAMA nan, Prev Close 0.004097, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:45:00
# 检查交叉：时间 2025-04-16 07:45:00, Close 0.003950, KAMA nan, Prev Close 0.003989, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:46:00
# 检查交叉：时间 2025-04-16 07:46:00, Close 0.003927, KAMA nan, Prev Close 0.003950, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:47:00
# 检查交叉：时间 2025-04-16 07:47:00, Close 0.004005, KAMA nan, Prev Close 0.003927, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:48:00
# 检查交叉：时间 2025-04-16 07:48:00, Close 0.004041, KAMA nan, Prev Close 0.004005, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:49:00
# 检查交叉：时间 2025-04-16 07:49:00, Close 0.004075, KAMA nan, Prev Close 0.004041, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:50:00
# 检查交叉：时间 2025-04-16 07:50:00, Close 0.004044, KAMA nan, Prev Close 0.004075, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:51:00
# 检查交叉：时间 2025-04-16 07:51:00, Close 0.004008, KAMA nan, Prev Close 0.004044, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:52:00
# 检查交叉：时间 2025-04-16 07:52:00, Close 0.003902, KAMA nan, Prev Close 0.004008, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:53:00
# 检查交叉：时间 2025-04-16 07:53:00, Close 0.003892, KAMA nan, Prev Close 0.003902, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:54:00
# 检查交叉：时间 2025-04-16 07:54:00, Close 0.004001, KAMA nan, Prev Close 0.003892, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:55:00
# 检查交叉：时间 2025-04-16 07:55:00, Close 0.003978, KAMA nan, Prev Close 0.004001, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:56:00
# 检查交叉：时间 2025-04-16 07:56:00, Close 0.003919, KAMA nan, Prev Close 0.003978, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:57:00
# 检查交叉：时间 2025-04-16 07:57:00, Close 0.003840, KAMA nan, Prev Close 0.003919, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:58:00
# 检查交叉：时间 2025-04-16 07:58:00, Close 0.003940, KAMA nan, Prev Close 0.003840, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 07:59:00
# 检查交叉：时间 2025-04-16 07:59:00, Close 0.004036, KAMA nan, Prev Close 0.003940, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:00:00
# 检查交叉：时间 2025-04-16 08:00:00, Close 0.004068, KAMA nan, Prev Close 0.004036, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:01:00
# 检查交叉：时间 2025-04-16 08:01:00, Close 0.004200, KAMA nan, Prev Close 0.004068, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:02:00
# 检查交叉：时间 2025-04-16 08:02:00, Close 0.004238, KAMA nan, Prev Close 0.004200, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:03:00
# 检查交叉：时间 2025-04-16 08:03:00, Close 0.004070, KAMA nan, Prev Close 0.004238, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:04:00
# 检查交叉：时间 2025-04-16 08:04:00, Close 0.004092, KAMA nan, Prev Close 0.004070, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:05:00
# 检查交叉：时间 2025-04-16 08:05:00, Close 0.004091, KAMA nan, Prev Close 0.004092, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:06:00
# 检查交叉：时间 2025-04-16 08:06:00, Close 0.004186, KAMA nan, Prev Close 0.004091, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:07:00
# 检查交叉：时间 2025-04-16 08:07:00, Close 0.004123, KAMA nan, Prev Close 0.004186, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:08:00
# 检查交叉：时间 2025-04-16 08:08:00, Close 0.004070, KAMA nan, Prev Close 0.004123, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:09:00
# 检查交叉：时间 2025-04-16 08:09:00, Close 0.004080, KAMA nan, Prev Close 0.004070, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:10:00
# 检查交叉：时间 2025-04-16 08:10:00, Close 0.004083, KAMA nan, Prev Close 0.004080, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:11:00
# 检查交叉：时间 2025-04-16 08:11:00, Close 0.004147, KAMA nan, Prev Close 0.004083, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:12:00
# 检查交叉：时间 2025-04-16 08:12:00, Close 0.004086, KAMA nan, Prev Close 0.004147, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:13:00
# 检查交叉：时间 2025-04-16 08:13:00, Close 0.004093, KAMA nan, Prev Close 0.004086, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:14:00
# 检查交叉：时间 2025-04-16 08:14:00, Close 0.004077, KAMA nan, Prev Close 0.004093, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:15:00
# 检查交叉：时间 2025-04-16 08:15:00, Close 0.004105, KAMA nan, Prev Close 0.004077, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:16:00
# 检查交叉：时间 2025-04-16 08:16:00, Close 0.004136, KAMA nan, Prev Close 0.004105, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:17:00
# 检查交叉：时间 2025-04-16 08:17:00, Close 0.004084, KAMA nan, Prev Close 0.004136, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:18:00
# 检查交叉：时间 2025-04-16 08:18:00, Close 0.004010, KAMA nan, Prev Close 0.004084, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:19:00
# 检查交叉：时间 2025-04-16 08:19:00, Close 0.004059, KAMA nan, Prev Close 0.004010, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:20:00
# 检查交叉：时间 2025-04-16 08:20:00, Close 0.004054, KAMA nan, Prev Close 0.004059, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:21:00
# 检查交叉：时间 2025-04-16 08:21:00, Close 0.004118, KAMA nan, Prev Close 0.004054, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:22:00
# 检查交叉：时间 2025-04-16 08:22:00, Close 0.004079, KAMA nan, Prev Close 0.004118, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:23:00
# 检查交叉：时间 2025-04-16 08:23:00, Close 0.004130, KAMA nan, Prev Close 0.004079, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:24:00
# 检查交叉：时间 2025-04-16 08:24:00, Close 0.004242, KAMA nan, Prev Close 0.004130, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:25:00
# 检查交叉：时间 2025-04-16 08:25:00, Close 0.004236, KAMA nan, Prev Close 0.004242, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:26:00
# 检查交叉：时间 2025-04-16 08:26:00, Close 0.004245, KAMA nan, Prev Close 0.004236, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:27:00
# 检查交叉：时间 2025-04-16 08:27:00, Close 0.004337, KAMA nan, Prev Close 0.004245, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:28:00
# 检查交叉：时间 2025-04-16 08:28:00, Close 0.004374, KAMA nan, Prev Close 0.004337, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:29:00
# 检查交叉：时间 2025-04-16 08:29:00, Close 0.004298, KAMA nan, Prev Close 0.004374, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:30:00
# 检查交叉：时间 2025-04-16 08:30:00, Close 0.004300, KAMA nan, Prev Close 0.004298, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:31:00
# 检查交叉：时间 2025-04-16 08:31:00, Close 0.004239, KAMA nan, Prev Close 0.004300, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:32:00
# 检查交叉：时间 2025-04-16 08:32:00, Close 0.004292, KAMA nan, Prev Close 0.004239, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:33:00
# 检查交叉：时间 2025-04-16 08:33:00, Close 0.004352, KAMA nan, Prev Close 0.004292, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:34:00
# 检查交叉：时间 2025-04-16 08:34:00, Close 0.004430, KAMA nan, Prev Close 0.004352, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:35:00
# 检查交叉：时间 2025-04-16 08:35:00, Close 0.004493, KAMA nan, Prev Close 0.004430, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:36:00
# 检查交叉：时间 2025-04-16 08:36:00, Close 0.004600, KAMA nan, Prev Close 0.004493, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:37:00
# 检查交叉：时间 2025-04-16 08:37:00, Close 0.004658, KAMA nan, Prev Close 0.004600, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:38:00
# 检查交叉：时间 2025-04-16 08:38:00, Close 0.004704, KAMA nan, Prev Close 0.004658, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:39:00
# 检查交叉：时间 2025-04-16 08:39:00, Close 0.004702, KAMA nan, Prev Close 0.004704, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:40:00
# 检查交叉：时间 2025-04-16 08:40:00, Close 0.004683, KAMA nan, Prev Close 0.004702, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:41:00
# 检查交叉：时间 2025-04-16 08:41:00, Close 0.004681, KAMA nan, Prev Close 0.004683, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:42:00
# 检查交叉：时间 2025-04-16 08:42:00, Close 0.004754, KAMA nan, Prev Close 0.004681, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:43:00
# 检查交叉：时间 2025-04-16 08:43:00, Close 0.004671, KAMA nan, Prev Close 0.004754, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:44:00
# 检查交叉：时间 2025-04-16 08:44:00, Close 0.004697, KAMA nan, Prev Close 0.004671, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:45:00
# 检查交叉：时间 2025-04-16 08:45:00, Close 0.004704, KAMA nan, Prev Close 0.004697, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:46:00
# 检查交叉：时间 2025-04-16 08:46:00, Close 0.004731, KAMA nan, Prev Close 0.004704, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:47:00
# 检查交叉：时间 2025-04-16 08:47:00, Close 0.004786, KAMA nan, Prev Close 0.004731, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:48:00
# 检查交叉：时间 2025-04-16 08:48:00, Close 0.004648, KAMA nan, Prev Close 0.004786, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:49:00
# 检查交叉：时间 2025-04-16 08:49:00, Close 0.004643, KAMA nan, Prev Close 0.004648, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:50:00
# 检查交叉：时间 2025-04-16 08:50:00, Close 0.004701, KAMA nan, Prev Close 0.004643, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:51:00
# 检查交叉：时间 2025-04-16 08:51:00, Close 0.004659, KAMA nan, Prev Close 0.004701, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:52:00
# 检查交叉：时间 2025-04-16 08:52:00, Close 0.004549, KAMA nan, Prev Close 0.004659, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:53:00
# 检查交叉：时间 2025-04-16 08:53:00, Close 0.004582, KAMA nan, Prev Close 0.004549, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:54:00
# 检查交叉：时间 2025-04-16 08:54:00, Close 0.004505, KAMA nan, Prev Close 0.004582, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:55:00
# 检查交叉：时间 2025-04-16 08:55:00, Close 0.004579, KAMA nan, Prev Close 0.004505, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:56:00
# 检查交叉：时间 2025-04-16 08:56:00, Close 0.004572, KAMA nan, Prev Close 0.004579, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:57:00
# 检查交叉：时间 2025-04-16 08:57:00, Close 0.004643, KAMA nan, Prev Close 0.004572, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:58:00
# 检查交叉：时间 2025-04-16 08:58:00, Close 0.004646, KAMA nan, Prev Close 0.004643, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 08:59:00
# 检查交叉：时间 2025-04-16 08:59:00, Close 0.004680, KAMA nan, Prev Close 0.004646, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:00:00
# 检查交叉：时间 2025-04-16 09:00:00, Close 0.004655, KAMA nan, Prev Close 0.004680, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:01:00
# 检查交叉：时间 2025-04-16 09:01:00, Close 0.004698, KAMA nan, Prev Close 0.004655, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:02:00
# 检查交叉：时间 2025-04-16 09:02:00, Close 0.004745, KAMA nan, Prev Close 0.004698, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:03:00
# 检查交叉：时间 2025-04-16 09:03:00, Close 0.004766, KAMA nan, Prev Close 0.004745, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:04:00
# 检查交叉：时间 2025-04-16 09:04:00, Close 0.004855, KAMA nan, Prev Close 0.004766, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:05:00
# 检查交叉：时间 2025-04-16 09:05:00, Close 0.004950, KAMA nan, Prev Close 0.004855, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:06:00
# 检查交叉：时间 2025-04-16 09:06:00, Close 0.005000, KAMA nan, Prev Close 0.004950, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:07:00
# 检查交叉：时间 2025-04-16 09:07:00, Close 0.004865, KAMA nan, Prev Close 0.005000, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:08:00
# 检查交叉：时间 2025-04-16 09:08:00, Close 0.004813, KAMA nan, Prev Close 0.004865, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:09:00
# 检查交叉：时间 2025-04-16 09:09:00, Close 0.004791, KAMA nan, Prev Close 0.004813, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:10:00
# 检查交叉：时间 2025-04-16 09:10:00, Close 0.004782, KAMA nan, Prev Close 0.004791, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:11:00
# 检查交叉：时间 2025-04-16 09:11:00, Close 0.004767, KAMA nan, Prev Close 0.004782, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:12:00
# 检查交叉：时间 2025-04-16 09:12:00, Close 0.004740, KAMA nan, Prev Close 0.004767, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:13:00
# 检查交叉：时间 2025-04-16 09:13:00, Close 0.004792, KAMA nan, Prev Close 0.004740, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:14:00
# 检查交叉：时间 2025-04-16 09:14:00, Close 0.004768, KAMA nan, Prev Close 0.004792, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:15:00
# 检查交叉：时间 2025-04-16 09:15:00, Close 0.004773, KAMA nan, Prev Close 0.004768, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:16:00
# 检查交叉：时间 2025-04-16 09:16:00, Close 0.004850, KAMA nan, Prev Close 0.004773, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:17:00
# 检查交叉：时间 2025-04-16 09:17:00, Close 0.004854, KAMA nan, Prev Close 0.004850, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:18:00
# 检查交叉：时间 2025-04-16 09:18:00, Close 0.004818, KAMA nan, Prev Close 0.004854, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:19:00
# 检查交叉：时间 2025-04-16 09:19:00, Close 0.004843, KAMA nan, Prev Close 0.004818, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:20:00
# 检查交叉：时间 2025-04-16 09:20:00, Close 0.004853, KAMA nan, Prev Close 0.004843, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:21:00
# 检查交叉：时间 2025-04-16 09:21:00, Close 0.004883, KAMA nan, Prev Close 0.004853, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:22:00
# 检查交叉：时间 2025-04-16 09:22:00, Close 0.004897, KAMA nan, Prev Close 0.004883, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:23:00
# 检查交叉：时间 2025-04-16 09:23:00, Close 0.004877, KAMA nan, Prev Close 0.004897, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:24:00
# 检查交叉：时间 2025-04-16 09:24:00, Close 0.004780, KAMA nan, Prev Close 0.004877, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:25:00
# 检查交叉：时间 2025-04-16 09:25:00, Close 0.004771, KAMA nan, Prev Close 0.004780, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:26:00
# 检查交叉：时间 2025-04-16 09:26:00, Close 0.004833, KAMA nan, Prev Close 0.004771, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:27:00
# 检查交叉：时间 2025-04-16 09:27:00, Close 0.004879, KAMA nan, Prev Close 0.004833, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:28:00
# 检查交叉：时间 2025-04-16 09:28:00, Close 0.004824, KAMA nan, Prev Close 0.004879, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:29:00
# 检查交叉：时间 2025-04-16 09:29:00, Close 0.004777, KAMA nan, Prev Close 0.004824, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:30:00
# 检查交叉：时间 2025-04-16 09:30:00, Close 0.004810, KAMA nan, Prev Close 0.004777, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:31:00
# 检查交叉：时间 2025-04-16 09:31:00, Close 0.004859, KAMA nan, Prev Close 0.004810, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:32:00
# 检查交叉：时间 2025-04-16 09:32:00, Close 0.005034, KAMA nan, Prev Close 0.004859, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:33:00
# 检查交叉：时间 2025-04-16 09:33:00, Close 0.005043, KAMA nan, Prev Close 0.005034, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:34:00
# 检查交叉：时间 2025-04-16 09:34:00, Close 0.005005, KAMA nan, Prev Close 0.005043, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:35:00
# 检查交叉：时间 2025-04-16 09:35:00, Close 0.005035, KAMA nan, Prev Close 0.005005, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:36:00
# 检查交叉：时间 2025-04-16 09:36:00, Close 0.005007, KAMA nan, Prev Close 0.005035, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:37:00
# 检查交叉：时间 2025-04-16 09:37:00, Close 0.005056, KAMA nan, Prev Close 0.005007, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:38:00
# 检查交叉：时间 2025-04-16 09:38:00, Close 0.004932, KAMA nan, Prev Close 0.005056, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:39:00
# 检查交叉：时间 2025-04-16 09:39:00, Close 0.004947, KAMA nan, Prev Close 0.004932, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:40:00
# 检查交叉：时间 2025-04-16 09:40:00, Close 0.004941, KAMA nan, Prev Close 0.004947, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:41:00
# 检查交叉：时间 2025-04-16 09:41:00, Close 0.004889, KAMA nan, Prev Close 0.004941, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:42:00
# 检查交叉：时间 2025-04-16 09:42:00, Close 0.004919, KAMA nan, Prev Close 0.004889, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:43:00
# 检查交叉：时间 2025-04-16 09:43:00, Close 0.004947, KAMA nan, Prev Close 0.004919, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:44:00
# 检查交叉：时间 2025-04-16 09:44:00, Close 0.004971, KAMA nan, Prev Close 0.004947, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:45:00
# 检查交叉：时间 2025-04-16 09:45:00, Close 0.004983, KAMA nan, Prev Close 0.004971, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:46:00
# 检查交叉：时间 2025-04-16 09:46:00, Close 0.004956, KAMA nan, Prev Close 0.004983, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:47:00
# 检查交叉：时间 2025-04-16 09:47:00, Close 0.004805, KAMA nan, Prev Close 0.004956, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:48:00
# 检查交叉：时间 2025-04-16 09:48:00, Close 0.004783, KAMA nan, Prev Close 0.004805, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:49:00
# 检查交叉：时间 2025-04-16 09:49:00, Close 0.004784, KAMA nan, Prev Close 0.004783, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:50:00
# 检查交叉：时间 2025-04-16 09:50:00, Close 0.004813, KAMA nan, Prev Close 0.004784, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:51:00
# 检查交叉：时间 2025-04-16 09:51:00, Close 0.004787, KAMA nan, Prev Close 0.004813, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:52:00
# 检查交叉：时间 2025-04-16 09:52:00, Close 0.004741, KAMA nan, Prev Close 0.004787, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:53:00
# 检查交叉：时间 2025-04-16 09:53:00, Close 0.004685, KAMA nan, Prev Close 0.004741, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:54:00
# 检查交叉：时间 2025-04-16 09:54:00, Close 0.004793, KAMA nan, Prev Close 0.004685, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:55:00
# 检查交叉：时间 2025-04-16 09:55:00, Close 0.004820, KAMA nan, Prev Close 0.004793, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:56:00
# 检查交叉：时间 2025-04-16 09:56:00, Close 0.004841, KAMA nan, Prev Close 0.004820, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:57:00
# 检查交叉：时间 2025-04-16 09:57:00, Close 0.004785, KAMA nan, Prev Close 0.004841, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:58:00
# 检查交叉：时间 2025-04-16 09:58:00, Close 0.004802, KAMA nan, Prev Close 0.004785, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 09:59:00
# 检查交叉：时间 2025-04-16 09:59:00, Close 0.004606, KAMA nan, Prev Close 0.004802, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:00:00
# 检查交叉：时间 2025-04-16 10:00:00, Close 0.004640, KAMA nan, Prev Close 0.004606, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:01:00
# 检查交叉：时间 2025-04-16 10:01:00, Close 0.004664, KAMA nan, Prev Close 0.004640, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:02:00
# 检查交叉：时间 2025-04-16 10:02:00, Close 0.004724, KAMA nan, Prev Close 0.004664, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:03:00
# 检查交叉：时间 2025-04-16 10:03:00, Close 0.004634, KAMA nan, Prev Close 0.004724, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:04:00
# 检查交叉：时间 2025-04-16 10:04:00, Close 0.004580, KAMA nan, Prev Close 0.004634, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:05:00
# 检查交叉：时间 2025-04-16 10:05:00, Close 0.004606, KAMA nan, Prev Close 0.004580, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:06:00
# 检查交叉：时间 2025-04-16 10:06:00, Close 0.004686, KAMA nan, Prev Close 0.004606, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:07:00
# 检查交叉：时间 2025-04-16 10:07:00, Close 0.004753, KAMA nan, Prev Close 0.004686, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:08:00
# 检查交叉：时间 2025-04-16 10:08:00, Close 0.004760, KAMA nan, Prev Close 0.004753, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:09:00
# 检查交叉：时间 2025-04-16 10:09:00, Close 0.004766, KAMA nan, Prev Close 0.004760, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:10:00
# 检查交叉：时间 2025-04-16 10:10:00, Close 0.004756, KAMA nan, Prev Close 0.004766, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:11:00
# 检查交叉：时间 2025-04-16 10:11:00, Close 0.004902, KAMA nan, Prev Close 0.004756, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:12:00
# 检查交叉：时间 2025-04-16 10:12:00, Close 0.004695, KAMA nan, Prev Close 0.004902, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:13:00
# 检查交叉：时间 2025-04-16 10:13:00, Close 0.004787, KAMA nan, Prev Close 0.004695, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:14:00
# 检查交叉：时间 2025-04-16 10:14:00, Close 0.004912, KAMA nan, Prev Close 0.004787, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:15:00
# 检查交叉：时间 2025-04-16 10:15:00, Close 0.004791, KAMA nan, Prev Close 0.004912, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:16:00
# 检查交叉：时间 2025-04-16 10:16:00, Close 0.004717, KAMA nan, Prev Close 0.004791, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:17:00
# 检查交叉：时间 2025-04-16 10:17:00, Close 0.004822, KAMA nan, Prev Close 0.004717, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:18:00
# 检查交叉：时间 2025-04-16 10:18:00, Close 0.004829, KAMA nan, Prev Close 0.004822, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:19:00
# 检查交叉：时间 2025-04-16 10:19:00, Close 0.004816, KAMA nan, Prev Close 0.004829, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:20:00
# 检查交叉：时间 2025-04-16 10:20:00, Close 0.004740, KAMA nan, Prev Close 0.004816, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:21:00
# 检查交叉：时间 2025-04-16 10:21:00, Close 0.004561, KAMA nan, Prev Close 0.004740, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:22:00
# 检查交叉：时间 2025-04-16 10:22:00, Close 0.004553, KAMA nan, Prev Close 0.004561, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:23:00
# 检查交叉：时间 2025-04-16 10:23:00, Close 0.004580, KAMA nan, Prev Close 0.004553, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:24:00
# 检查交叉：时间 2025-04-16 10:24:00, Close 0.004686, KAMA nan, Prev Close 0.004580, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:25:00
# 检查交叉：时间 2025-04-16 10:25:00, Close 0.004779, KAMA nan, Prev Close 0.004686, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:26:00
# 检查交叉：时间 2025-04-16 10:26:00, Close 0.004843, KAMA nan, Prev Close 0.004779, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:27:00
# 检查交叉：时间 2025-04-16 10:27:00, Close 0.004802, KAMA nan, Prev Close 0.004843, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:28:00
# 检查交叉：时间 2025-04-16 10:28:00, Close 0.004739, KAMA nan, Prev Close 0.004802, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:29:00
# 检查交叉：时间 2025-04-16 10:29:00, Close 0.004730, KAMA nan, Prev Close 0.004739, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:30:00
# 检查交叉：时间 2025-04-16 10:30:00, Close 0.004750, KAMA nan, Prev Close 0.004730, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:31:00
# 检查交叉：时间 2025-04-16 10:31:00, Close 0.004649, KAMA nan, Prev Close 0.004750, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:32:00
# 检查交叉：时间 2025-04-16 10:32:00, Close 0.004721, KAMA nan, Prev Close 0.004649, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:33:00
# 检查交叉：时间 2025-04-16 10:33:00, Close 0.004697, KAMA nan, Prev Close 0.004721, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:34:00
# 检查交叉：时间 2025-04-16 10:34:00, Close 0.004846, KAMA nan, Prev Close 0.004697, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:35:00
# 检查交叉：时间 2025-04-16 10:35:00, Close 0.004904, KAMA nan, Prev Close 0.004846, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:36:00
# 检查交叉：时间 2025-04-16 10:36:00, Close 0.005005, KAMA nan, Prev Close 0.004904, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:37:00
# 检查交叉：时间 2025-04-16 10:37:00, Close 0.005085, KAMA nan, Prev Close 0.005005, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:38:00
# 检查交叉：时间 2025-04-16 10:38:00, Close 0.005206, KAMA nan, Prev Close 0.005085, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:39:00
# 检查交叉：时间 2025-04-16 10:39:00, Close 0.005181, KAMA nan, Prev Close 0.005206, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:40:00
# 检查交叉：时间 2025-04-16 10:40:00, Close 0.005168, KAMA nan, Prev Close 0.005181, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:41:00
# 检查交叉：时间 2025-04-16 10:41:00, Close 0.005167, KAMA nan, Prev Close 0.005168, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:42:00
# 检查交叉：时间 2025-04-16 10:42:00, Close 0.005054, KAMA nan, Prev Close 0.005167, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:43:00
# 检查交叉：时间 2025-04-16 10:43:00, Close 0.005023, KAMA nan, Prev Close 0.005054, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:44:00
# 检查交叉：时间 2025-04-16 10:44:00, Close 0.005072, KAMA nan, Prev Close 0.005023, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:45:00
# 检查交叉：时间 2025-04-16 10:45:00, Close 0.005017, KAMA nan, Prev Close 0.005072, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:46:00
# 检查交叉：时间 2025-04-16 10:46:00, Close 0.005069, KAMA nan, Prev Close 0.005017, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:47:00
# 检查交叉：时间 2025-04-16 10:47:00, Close 0.005061, KAMA nan, Prev Close 0.005069, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:48:00
# 检查交叉：时间 2025-04-16 10:48:00, Close 0.005054, KAMA nan, Prev Close 0.005061, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:49:00
# 检查交叉：时间 2025-04-16 10:49:00, Close 0.005060, KAMA nan, Prev Close 0.005054, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:50:00
# 检查交叉：时间 2025-04-16 10:50:00, Close 0.005037, KAMA nan, Prev Close 0.005060, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:51:00
# 检查交叉：时间 2025-04-16 10:51:00, Close 0.005190, KAMA nan, Prev Close 0.005037, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:52:00
# 检查交叉：时间 2025-04-16 10:52:00, Close 0.005257, KAMA nan, Prev Close 0.005190, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:53:00
# 检查交叉：时间 2025-04-16 10:53:00, Close 0.005381, KAMA nan, Prev Close 0.005257, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 10:54:00
# ...
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:28:00
# 检查交叉：时间 2025-04-16 13:28:00, Close 0.004865, KAMA nan, Prev Close 0.004884, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:29:00
# 检查交叉：时间 2025-04-16 13:29:00, Close 0.004843, KAMA nan, Prev Close 0.004865, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:30:00
# 检查交叉：时间 2025-04-16 13:30:00, Close 0.004853, KAMA nan, Prev Close 0.004843, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:31:00
# 检查交叉：时间 2025-04-16 13:31:00, Close 0.004759, KAMA nan, Prev Close 0.004853, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:32:00
# 检查交叉：时间 2025-04-16 13:32:00, Close 0.004803, KAMA nan, Prev Close 0.004759, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:33:00
# 检查交叉：时间 2025-04-16 13:33:00, Close 0.004708, KAMA nan, Prev Close 0.004803, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:34:00
# 检查交叉：时间 2025-04-16 13:34:00, Close 0.004747, KAMA nan, Prev Close 0.004708, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:35:00
# 检查交叉：时间 2025-04-16 13:35:00, Close 0.004712, KAMA nan, Prev Close 0.004747, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:36:00
# 检查交叉：时间 2025-04-16 13:36:00, Close 0.004705, KAMA nan, Prev Close 0.004712, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:37:00
# 检查交叉：时间 2025-04-16 13:37:00, Close 0.004697, KAMA nan, Prev Close 0.004705, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:38:00
# 检查交叉：时间 2025-04-16 13:38:00, Close 0.004750, KAMA nan, Prev Close 0.004697, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:39:00
# 检查交叉：时间 2025-04-16 13:39:00, Close 0.004730, KAMA nan, Prev Close 0.004750, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:40:00
# 检查交叉：时间 2025-04-16 13:40:00, Close 0.004778, KAMA nan, Prev Close 0.004730, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:41:00
# 检查交叉：时间 2025-04-16 13:41:00, Close 0.004872, KAMA nan, Prev Close 0.004778, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:42:00
# 检查交叉：时间 2025-04-16 13:42:00, Close 0.004718, KAMA nan, Prev Close 0.004872, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:43:00
# 检查交叉：时间 2025-04-16 13:43:00, Close 0.004685, KAMA nan, Prev Close 0.004718, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:44:00
# 检查交叉：时间 2025-04-16 13:44:00, Close 0.004670, KAMA nan, Prev Close 0.004685, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:45:00
# 检查交叉：时间 2025-04-16 13:45:00, Close 0.004703, KAMA nan, Prev Close 0.004670, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:46:00
# 检查交叉：时间 2025-04-16 13:46:00, Close 0.004702, KAMA nan, Prev Close 0.004703, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:47:00
# 检查交叉：时间 2025-04-16 13:47:00, Close 0.004675, KAMA nan, Prev Close 0.004702, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:48:00
# 检查交叉：时间 2025-04-16 13:48:00, Close 0.004566, KAMA nan, Prev Close 0.004675, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:49:00
# 检查交叉：时间 2025-04-16 13:49:00, Close 0.004529, KAMA nan, Prev Close 0.004566, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:50:00
# 检查交叉：时间 2025-04-16 13:50:00, Close 0.004590, KAMA nan, Prev Close 0.004529, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:51:00
# 检查交叉：时间 2025-04-16 13:51:00, Close 0.004762, KAMA nan, Prev Close 0.004590, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:52:00
# 检查交叉：时间 2025-04-16 13:52:00, Close 0.004788, KAMA nan, Prev Close 0.004762, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:53:00
# 检查交叉：时间 2025-04-16 13:53:00, Close 0.004717, KAMA nan, Prev Close 0.004788, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:54:00
# 检查交叉：时间 2025-04-16 13:54:00, Close 0.004798, KAMA nan, Prev Close 0.004717, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:55:00
# 检查交叉：时间 2025-04-16 13:55:00, Close 0.004722, KAMA nan, Prev Close 0.004798, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:56:00
# 检查交叉：时间 2025-04-16 13:56:00, Close 0.004807, KAMA nan, Prev Close 0.004722, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:57:00
# 检查交叉：时间 2025-04-16 13:57:00, Close 0.004686, KAMA nan, Prev Close 0.004807, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:58:00
# 检查交叉：时间 2025-04-16 13:58:00, Close 0.004694, KAMA nan, Prev Close 0.004686, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 13:59:00
# 检查交叉：时间 2025-04-16 13:59:00, Close 0.004765, KAMA nan, Prev Close 0.004694, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:00:00
# 检查交叉：时间 2025-04-16 14:00:00, Close 0.004712, KAMA nan, Prev Close 0.004765, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:01:00
# 检查交叉：时间 2025-04-16 14:01:00, Close 0.004722, KAMA nan, Prev Close 0.004712, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:02:00
# 检查交叉：时间 2025-04-16 14:02:00, Close 0.004664, KAMA nan, Prev Close 0.004722, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:03:00
# 检查交叉：时间 2025-04-16 14:03:00, Close 0.004780, KAMA nan, Prev Close 0.004664, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:04:00
# 检查交叉：时间 2025-04-16 14:04:00, Close 0.004645, KAMA nan, Prev Close 0.004780, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:05:00
# 检查交叉：时间 2025-04-16 14:05:00, Close 0.004683, KAMA nan, Prev Close 0.004645, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:06:00
# 检查交叉：时间 2025-04-16 14:06:00, Close 0.004598, KAMA nan, Prev Close 0.004683, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:07:00
# 检查交叉：时间 2025-04-16 14:07:00, Close 0.004572, KAMA nan, Prev Close 0.004598, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:08:00
# 检查交叉：时间 2025-04-16 14:08:00, Close 0.004470, KAMA nan, Prev Close 0.004572, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:09:00
# 检查交叉：时间 2025-04-16 14:09:00, Close 0.004317, KAMA nan, Prev Close 0.004470, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:10:00
# 检查交叉：时间 2025-04-16 14:10:00, Close 0.004312, KAMA nan, Prev Close 0.004317, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:11:00
# 检查交叉：时间 2025-04-16 14:11:00, Close 0.004190, KAMA nan, Prev Close 0.004312, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:12:00
# 检查交叉：时间 2025-04-16 14:12:00, Close 0.004175, KAMA nan, Prev Close 0.004190, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:13:00
# 检查交叉：时间 2025-04-16 14:13:00, Close 0.004156, KAMA nan, Prev Close 0.004175, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:14:00
# 检查交叉：时间 2025-04-16 14:14:00, Close 0.004113, KAMA nan, Prev Close 0.004156, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:15:00
# 检查交叉：时间 2025-04-16 14:15:00, Close 0.004012, KAMA nan, Prev Close 0.004113, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:16:00
# 检查交叉：时间 2025-04-16 14:16:00, Close 0.003895, KAMA nan, Prev Close 0.004012, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:17:00
# 检查交叉：时间 2025-04-16 14:17:00, Close 0.003863, KAMA nan, Prev Close 0.003895, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:18:00
# 检查交叉：时间 2025-04-16 14:18:00, Close 0.003835, KAMA nan, Prev Close 0.003863, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:19:00
# 检查交叉：时间 2025-04-16 14:19:00, Close 0.003839, KAMA nan, Prev Close 0.003835, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:20:00
# 检查交叉：时间 2025-04-16 14:20:00, Close 0.003794, KAMA nan, Prev Close 0.003839, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:21:00
# 检查交叉：时间 2025-04-16 14:21:00, Close 0.003708, KAMA nan, Prev Close 0.003794, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:22:00
# 检查交叉：时间 2025-04-16 14:22:00, Close 0.003753, KAMA nan, Prev Close 0.003708, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:23:00
# 检查交叉：时间 2025-04-16 14:23:00, Close 0.003826, KAMA nan, Prev Close 0.003753, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:24:00
# 检查交叉：时间 2025-04-16 14:24:00, Close 0.003875, KAMA nan, Prev Close 0.003826, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:25:00
# 检查交叉：时间 2025-04-16 14:25:00, Close 0.003815, KAMA nan, Prev Close 0.003875, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:26:00
# 检查交叉：时间 2025-04-16 14:26:00, Close 0.003812, KAMA nan, Prev Close 0.003815, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:27:00
# 检查交叉：时间 2025-04-16 14:27:00, Close 0.003928, KAMA nan, Prev Close 0.003812, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:28:00
# 检查交叉：时间 2025-04-16 14:28:00, Close 0.003878, KAMA nan, Prev Close 0.003928, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:29:00
# 检查交叉：时间 2025-04-16 14:29:00, Close 0.003795, KAMA nan, Prev Close 0.003878, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:30:00
# 检查交叉：时间 2025-04-16 14:30:00, Close 0.003826, KAMA nan, Prev Close 0.003795, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:31:00
# 检查交叉：时间 2025-04-16 14:31:00, Close 0.003833, KAMA nan, Prev Close 0.003826, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:32:00
# 检查交叉：时间 2025-04-16 14:32:00, Close 0.003808, KAMA nan, Prev Close 0.003833, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:33:00
# 检查交叉：时间 2025-04-16 14:33:00, Close 0.003812, KAMA nan, Prev Close 0.003808, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:34:00
# 检查交叉：时间 2025-04-16 14:34:00, Close 0.003816, KAMA nan, Prev Close 0.003812, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:35:00
# 检查交叉：时间 2025-04-16 14:35:00, Close 0.003861, KAMA nan, Prev Close 0.003816, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:36:00
# 检查交叉：时间 2025-04-16 14:36:00, Close 0.003800, KAMA nan, Prev Close 0.003861, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:37:00
# 检查交叉：时间 2025-04-16 14:37:00, Close 0.003751, KAMA nan, Prev Close 0.003800, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:38:00
# 检查交叉：时间 2025-04-16 14:38:00, Close 0.003756, KAMA nan, Prev Close 0.003751, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:39:00
# 检查交叉：时间 2025-04-16 14:39:00, Close 0.003853, KAMA nan, Prev Close 0.003756, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:40:00
# 检查交叉：时间 2025-04-16 14:40:00, Close 0.003783, KAMA nan, Prev Close 0.003853, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:41:00
# 检查交叉：时间 2025-04-16 14:41:00, Close 0.003716, KAMA nan, Prev Close 0.003783, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:42:00
# 检查交叉：时间 2025-04-16 14:42:00, Close 0.003587, KAMA nan, Prev Close 0.003716, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:43:00
# 检查交叉：时间 2025-04-16 14:43:00, Close 0.003535, KAMA nan, Prev Close 0.003587, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:44:00
# 检查交叉：时间 2025-04-16 14:44:00, Close 0.003667, KAMA nan, Prev Close 0.003535, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:45:00
# 检查交叉：时间 2025-04-16 14:45:00, Close 0.003634, KAMA nan, Prev Close 0.003667, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:46:00
# 检查交叉：时间 2025-04-16 14:46:00, Close 0.003630, KAMA nan, Prev Close 0.003634, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:47:00
# 检查交叉：时间 2025-04-16 14:47:00, Close 0.003625, KAMA nan, Prev Close 0.003630, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:48:00
# 检查交叉：时间 2025-04-16 14:48:00, Close 0.003617, KAMA nan, Prev Close 0.003625, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:49:00
# 检查交叉：时间 2025-04-16 14:49:00, Close 0.003600, KAMA nan, Prev Close 0.003617, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:50:00
# 检查交叉：时间 2025-04-16 14:50:00, Close 0.003520, KAMA nan, Prev Close 0.003600, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:51:00
# 检查交叉：时间 2025-04-16 14:51:00, Close 0.003509, KAMA nan, Prev Close 0.003520, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:52:00
# 检查交叉：时间 2025-04-16 14:52:00, Close 0.003521, KAMA nan, Prev Close 0.003509, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:53:00
# 检查交叉：时间 2025-04-16 14:53:00, Close 0.003565, KAMA nan, Prev Close 0.003521, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:54:00
# 检查交叉：时间 2025-04-16 14:54:00, Close 0.003531, KAMA nan, Prev Close 0.003565, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:55:00
# 检查交叉：时间 2025-04-16 14:55:00, Close 0.003508, KAMA nan, Prev Close 0.003531, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:56:00
# 检查交叉：时间 2025-04-16 14:56:00, Close 0.003512, KAMA nan, Prev Close 0.003508, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:57:00
# 检查交叉：时间 2025-04-16 14:57:00, Close 0.003528, KAMA nan, Prev Close 0.003512, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:58:00
# 检查交叉：时间 2025-04-16 14:58:00, Close 0.003588, KAMA nan, Prev Close 0.003528, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 14:59:00
# 检查交叉：时间 2025-04-16 14:59:00, Close 0.003525, KAMA nan, Prev Close 0.003588, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:00:00
# 检查交叉：时间 2025-04-16 15:00:00, Close 0.003463, KAMA nan, Prev Close 0.003525, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:01:00
# 检查交叉：时间 2025-04-16 15:01:00, Close 0.003463, KAMA nan, Prev Close 0.003463, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:02:00
# 检查交叉：时间 2025-04-16 15:02:00, Close 0.003415, KAMA nan, Prev Close 0.003463, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:03:00
# 检查交叉：时间 2025-04-16 15:03:00, Close 0.003494, KAMA nan, Prev Close 0.003415, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:04:00
# 检查交叉：时间 2025-04-16 15:04:00, Close 0.003509, KAMA nan, Prev Close 0.003494, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:05:00
# 检查交叉：时间 2025-04-16 15:05:00, Close 0.003418, KAMA nan, Prev Close 0.003509, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:06:00
# 检查交叉：时间 2025-04-16 15:06:00, Close 0.003419, KAMA nan, Prev Close 0.003418, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:07:00
# 检查交叉：时间 2025-04-16 15:07:00, Close 0.003383, KAMA nan, Prev Close 0.003419, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:08:00
# 检查交叉：时间 2025-04-16 15:08:00, Close 0.003249, KAMA nan, Prev Close 0.003383, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:09:00
# 检查交叉：时间 2025-04-16 15:09:00, Close 0.003288, KAMA nan, Prev Close 0.003249, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:10:00
# 检查交叉：时间 2025-04-16 15:10:00, Close 0.003322, KAMA nan, Prev Close 0.003288, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:11:00
# 检查交叉：时间 2025-04-16 15:11:00, Close 0.003252, KAMA nan, Prev Close 0.003322, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:12:00
# 检查交叉：时间 2025-04-16 15:12:00, Close 0.003172, KAMA nan, Prev Close 0.003252, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:13:00
# 检查交叉：时间 2025-04-16 15:13:00, Close 0.003167, KAMA nan, Prev Close 0.003172, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:14:00
# 检查交叉：时间 2025-04-16 15:14:00, Close 0.003311, KAMA nan, Prev Close 0.003167, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:15:00
# 检查交叉：时间 2025-04-16 15:15:00, Close 0.003415, KAMA nan, Prev Close 0.003311, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:16:00
# 检查交叉：时间 2025-04-16 15:16:00, Close 0.003318, KAMA nan, Prev Close 0.003415, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 执行 next：时间 2025-04-16 15:17:00
# 检查交叉：时间 2025-04-16 15:17:00, Close 0.003394, KAMA nan, Prev Close 0.003318, Prev KAMA nan
# 买入条件：False
# 卖出条件：False
# 回测完成：交易次数 0
# KAMA 范围：0.003243 - 0.005668
# RSI 范围：0.00 - 79.97
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
